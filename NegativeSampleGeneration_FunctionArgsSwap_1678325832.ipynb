# %%
import os
import clang
from clang.cindex import *
from copy import deepcopy
import time

# %%
Config.set_library_file("/home/dipu/anaconda3/lib/python3.9/site-packages/clang/native/libclang.so")

# %%
# create an index and parse the source code
index = Index.create()
root_cursor = index.parse("main.c").cursor

# %%
def print_ast(node, indent):
    try:
        print(" "*indent + node.spelling + " " + str(node.kind) + " " + str(node.type.spelling))
        for c in node.get_children():
            print_ast(c, indent+2)
    except ValueError:
        pass

print_ast(root_cursor, 0)
# Out:
# main.c CursorKind.TRANSLATION_UNIT
#   __u_char CursorKind.TYPEDEF_DECL __u_char
#   __u_short CursorKind.TYPEDEF_DECL __u_short
#   __u_int CursorKind.TYPEDEF_DECL __u_int
#   __u_long CursorKind.TYPEDEF_DECL __u_long
#   __int8_t CursorKind.TYPEDEF_DECL __int8_t
#   __uint8_t CursorKind.TYPEDEF_DECL __uint8_t
#   __int16_t CursorKind.TYPEDEF_DECL __int16_t
#   __uint16_t CursorKind.TYPEDEF_DECL __uint16_t
#   __int32_t CursorKind.TYPEDEF_DECL __int32_t
#   __uint32_t CursorKind.TYPEDEF_DECL __uint32_t
#   __int64_t CursorKind.TYPEDEF_DECL __int64_t
#   __uint64_t CursorKind.TYPEDEF_DECL __uint64_t
#   __int_least8_t CursorKind.TYPEDEF_DECL __int_least8_t
#     __int8_t CursorKind.TYPE_REF __int8_t
#   __uint_least8_t CursorKind.TYPEDEF_DECL __uint_least8_t
#     __uint8_t CursorKind.TYPE_REF __uint8_t
#   __int_least16_t CursorKind.TYPEDEF_DECL __int_least16_t
#     __int16_t CursorKind.TYPE_REF __int16_t
#   __uint_least16_t CursorKind.TYPEDEF_DECL __uint_least16_t
#     __uint16_t CursorKind.TYPE_REF __uint16_t
#   __int_least32_t CursorKind.TYPEDEF_DECL __int_least32_t
#     __int32_t CursorKind.TYPE_REF __int32_t
#   __uint_least32_t CursorKind.TYPEDEF_DECL __uint_least32_t
#     __uint32_t CursorKind.TYPE_REF __uint32_t
#   __int_least64_t CursorKind.TYPEDEF_DECL __int_least64_t
#     __int64_t CursorKind.TYPE_REF __int64_t
#   __uint_least64_t CursorKind.TYPEDEF_DECL __uint_least64_t
#     __uint64_t CursorKind.TYPE_REF __uint64_t
#   __quad_t CursorKind.TYPEDEF_DECL __quad_t
#   __u_quad_t CursorKind.TYPEDEF_DECL __u_quad_t
#   __intmax_t CursorKind.TYPEDEF_DECL __intmax_t
#   __uintmax_t CursorKind.TYPEDEF_DECL __uintmax_t
#   __dev_t CursorKind.TYPEDEF_DECL __dev_t
#   __uid_t CursorKind.TYPEDEF_DECL __uid_t
#   __gid_t CursorKind.TYPEDEF_DECL __gid_t
#   __ino_t CursorKind.TYPEDEF_DECL __ino_t
#   __ino64_t CursorKind.TYPEDEF_DECL __ino64_t
#   __mode_t CursorKind.TYPEDEF_DECL __mode_t
#   __nlink_t CursorKind.TYPEDEF_DECL __nlink_t
#   __off_t CursorKind.TYPEDEF_DECL __off_t
#   __off64_t CursorKind.TYPEDEF_DECL __off64_t
#   __pid_t CursorKind.TYPEDEF_DECL __pid_t
#    CursorKind.STRUCT_DECL __fsid_t
#     __val CursorKind.FIELD_DECL int [2]
#        CursorKind.INTEGER_LITERAL int
#   __fsid_t CursorKind.TYPEDEF_DECL __fsid_t
#      CursorKind.STRUCT_DECL __fsid_t
#       __val CursorKind.FIELD_DECL int [2]
#          CursorKind.INTEGER_LITERAL int
#   __clock_t CursorKind.TYPEDEF_DECL __clock_t
#   __rlim_t CursorKind.TYPEDEF_DECL __rlim_t
#   __rlim64_t CursorKind.TYPEDEF_DECL __rlim64_t
#   __id_t CursorKind.TYPEDEF_DECL __id_t
#   __time_t CursorKind.TYPEDEF_DECL __time_t
#   __useconds_t CursorKind.TYPEDEF_DECL __useconds_t
#   __suseconds_t CursorKind.TYPEDEF_DECL __suseconds_t
#   __suseconds64_t CursorKind.TYPEDEF_DECL __suseconds64_t
#   __daddr_t CursorKind.TYPEDEF_DECL __daddr_t
#   __key_t CursorKind.TYPEDEF_DECL __key_t
#   __clockid_t CursorKind.TYPEDEF_DECL __clockid_t
#   __timer_t CursorKind.TYPEDEF_DECL __timer_t
#   __blksize_t CursorKind.TYPEDEF_DECL __blksize_t
#   __blkcnt_t CursorKind.TYPEDEF_DECL __blkcnt_t
#   __blkcnt64_t CursorKind.TYPEDEF_DECL __blkcnt64_t
#   __fsblkcnt_t CursorKind.TYPEDEF_DECL __fsblkcnt_t
#   __fsblkcnt64_t CursorKind.TYPEDEF_DECL __fsblkcnt64_t
#   __fsfilcnt_t CursorKind.TYPEDEF_DECL __fsfilcnt_t
#   __fsfilcnt64_t CursorKind.TYPEDEF_DECL __fsfilcnt64_t
#   __fsword_t CursorKind.TYPEDEF_DECL __fsword_t
#   __ssize_t CursorKind.TYPEDEF_DECL __ssize_t
#   __syscall_slong_t CursorKind.TYPEDEF_DECL __syscall_slong_t
#   __syscall_ulong_t CursorKind.TYPEDEF_DECL __syscall_ulong_t
#   __loff_t CursorKind.TYPEDEF_DECL __loff_t
#     __off64_t CursorKind.TYPE_REF __off64_t
#   __caddr_t CursorKind.TYPEDEF_DECL __caddr_t
#   __intptr_t CursorKind.TYPEDEF_DECL __intptr_t
#   __socklen_t CursorKind.TYPEDEF_DECL __socklen_t
#   __sig_atomic_t CursorKind.TYPEDEF_DECL __sig_atomic_t
#    CursorKind.STRUCT_DECL __mbstate_t
#     __count CursorKind.FIELD_DECL int
#      CursorKind.UNION_DECL union __mbstate_t::(anonymous at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#       __wch CursorKind.FIELD_DECL unsigned int
#       __wchb CursorKind.FIELD_DECL char [4]
#          CursorKind.INTEGER_LITERAL int
#     __value CursorKind.FIELD_DECL union (anonymous union at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#        CursorKind.UNION_DECL union __mbstate_t::(anonymous at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#         __wch CursorKind.FIELD_DECL unsigned int
#         __wchb CursorKind.FIELD_DECL char [4]
#            CursorKind.INTEGER_LITERAL int
#   __mbstate_t CursorKind.TYPEDEF_DECL __mbstate_t
#      CursorKind.STRUCT_DECL __mbstate_t
#       __count CursorKind.FIELD_DECL int
#        CursorKind.UNION_DECL union __mbstate_t::(anonymous at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#         __wch CursorKind.FIELD_DECL unsigned int
#         __wchb CursorKind.FIELD_DECL char [4]
#            CursorKind.INTEGER_LITERAL int
#       __value CursorKind.FIELD_DECL union (anonymous union at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#          CursorKind.UNION_DECL union __mbstate_t::(anonymous at /usr/include/x86_64-linux-gnu/bits/types/__mbstate_t.h:16:3)
#           __wch CursorKind.FIELD_DECL unsigned int
#           __wchb CursorKind.FIELD_DECL char [4]
#              CursorKind.INTEGER_LITERAL int
#   _G_fpos_t CursorKind.STRUCT_DECL struct _G_fpos_t
#     __pos CursorKind.FIELD_DECL __off_t
#       __off_t CursorKind.TYPE_REF __off_t
#     __state CursorKind.FIELD_DECL __mbstate_t
#       __mbstate_t CursorKind.TYPE_REF __mbstate_t
#   __fpos_t CursorKind.TYPEDEF_DECL __fpos_t
#     _G_fpos_t CursorKind.STRUCT_DECL struct _G_fpos_t
#       __pos CursorKind.FIELD_DECL __off_t
#         __off_t CursorKind.TYPE_REF __off_t
#       __state CursorKind.FIELD_DECL __mbstate_t
#         __mbstate_t CursorKind.TYPE_REF __mbstate_t
#   _G_fpos64_t CursorKind.STRUCT_DECL struct _G_fpos64_t
#     __pos CursorKind.FIELD_DECL __off64_t
#       __off64_t CursorKind.TYPE_REF __off64_t
#     __state CursorKind.FIELD_DECL __mbstate_t
#       __mbstate_t CursorKind.TYPE_REF __mbstate_t
#   __fpos64_t CursorKind.TYPEDEF_DECL __fpos64_t
#     _G_fpos64_t CursorKind.STRUCT_DECL struct _G_fpos64_t
#       __pos CursorKind.FIELD_DECL __off64_t
#         __off64_t CursorKind.TYPE_REF __off64_t
#       __state CursorKind.FIELD_DECL __mbstate_t
#         __mbstate_t CursorKind.TYPE_REF __mbstate_t
#   _IO_FILE CursorKind.STRUCT_DECL struct _IO_FILE
#   __FILE CursorKind.TYPEDEF_DECL __FILE
#     struct _IO_FILE CursorKind.TYPE_REF struct _IO_FILE
#   _IO_FILE CursorKind.STRUCT_DECL struct _IO_FILE
#   FILE CursorKind.TYPEDEF_DECL FILE
#     struct _IO_FILE CursorKind.TYPE_REF struct _IO_FILE
#   _IO_FILE CursorKind.STRUCT_DECL struct _IO_FILE
#   _IO_marker CursorKind.STRUCT_DECL struct _IO_marker
#   _IO_codecvt CursorKind.STRUCT_DECL struct _IO_codecvt
#   _IO_wide_data CursorKind.STRUCT_DECL struct _IO_wide_data
#   _IO_lock_t CursorKind.TYPEDEF_DECL _IO_lock_t
#   _IO_FILE CursorKind.STRUCT_DECL struct _IO_FILE
#     _flags CursorKind.FIELD_DECL int
#     _IO_read_ptr CursorKind.FIELD_DECL char *
#     _IO_read_end CursorKind.FIELD_DECL char *
#     _IO_read_base CursorKind.FIELD_DECL char *
#     _IO_write_base CursorKind.FIELD_DECL char *
#     _IO_write_ptr CursorKind.FIELD_DECL char *
#     _IO_write_end CursorKind.FIELD_DECL char *
#     _IO_buf_base CursorKind.FIELD_DECL char *
#     _IO_buf_end CursorKind.FIELD_DECL char *
#     _IO_save_base CursorKind.FIELD_DECL char *
#     _IO_backup_base CursorKind.FIELD_DECL char *
#     _IO_save_end CursorKind.FIELD_DECL char *
#     _markers CursorKind.FIELD_DECL struct _IO_marker *
#       struct _IO_marker CursorKind.TYPE_REF struct _IO_marker
#     _chain CursorKind.FIELD_DECL struct _IO_FILE *
#       struct _IO_FILE CursorKind.TYPE_REF struct _IO_FILE
#     _fileno CursorKind.FIELD_DECL int
#     _flags2 CursorKind.FIELD_DECL int
#     _old_offset CursorKind.FIELD_DECL __off_t
#       __off_t CursorKind.TYPE_REF __off_t
#     _cur_column CursorKind.FIELD_DECL unsigned short
#     _vtable_offset CursorKind.FIELD_DECL signed char
#     _shortbuf CursorKind.FIELD_DECL char [1]
#        CursorKind.INTEGER_LITERAL int
#     _lock CursorKind.FIELD_DECL _IO_lock_t *
#       _IO_lock_t CursorKind.TYPE_REF _IO_lock_t
#     _offset CursorKind.FIELD_DECL __off64_t
#       __off64_t CursorKind.TYPE_REF __off64_t
#     _codecvt CursorKind.FIELD_DECL struct _IO_codecvt *
#       struct _IO_codecvt CursorKind.TYPE_REF struct _IO_codecvt
#     _wide_data CursorKind.FIELD_DECL struct _IO_wide_data *
#       struct _IO_wide_data CursorKind.TYPE_REF struct _IO_wide_data
#     _freeres_list CursorKind.FIELD_DECL struct _IO_FILE *
#       struct _IO_FILE CursorKind.TYPE_REF struct _IO_FILE
#     _freeres_buf CursorKind.FIELD_DECL void *
#     __pad5 CursorKind.FIELD_DECL int
#     _mode CursorKind.FIELD_DECL int
#     _unused2 CursorKind.FIELD_DECL char
#   va_list CursorKind.TYPEDEF_DECL va_list
#   off_t CursorKind.TYPEDEF_DECL off_t
#     __off_t CursorKind.TYPE_REF __off_t
#   ssize_t CursorKind.TYPEDEF_DECL ssize_t
#     __ssize_t CursorKind.TYPE_REF __ssize_t
#   fpos_t CursorKind.TYPEDEF_DECL fpos_t
#     __fpos_t CursorKind.TYPE_REF __fpos_t
#   stdin CursorKind.VAR_DECL FILE *
#     FILE CursorKind.TYPE_REF FILE
#   stdout CursorKind.VAR_DECL FILE *
#     FILE CursorKind.TYPE_REF FILE
#   stderr CursorKind.VAR_DECL FILE *
#     FILE CursorKind.TYPE_REF FILE
#   remove CursorKind.FUNCTION_DECL int (const char *)
#      CursorKind.UNEXPOSED_ATTR
#     __filename CursorKind.PARM_DECL const char *
#   rename CursorKind.FUNCTION_DECL int (const char *, const char *)
#      CursorKind.UNEXPOSED_ATTR
#     __old CursorKind.PARM_DECL const char *
#     __new CursorKind.PARM_DECL const char *
#   renameat CursorKind.FUNCTION_DECL int (int, const char *, int, const char *)
#      CursorKind.UNEXPOSED_ATTR
#     __oldfd CursorKind.PARM_DECL int
#     __old CursorKind.PARM_DECL const char *
#     __newfd CursorKind.PARM_DECL int
#     __new CursorKind.PARM_DECL const char *
#   fclose CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   tmpfile CursorKind.FUNCTION_DECL FILE *(void)
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#   tmpnam CursorKind.FUNCTION_DECL char *(char *)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.PARM_DECL char [20]
#        CursorKind.INTEGER_LITERAL int
#   tmpnam_r CursorKind.FUNCTION_DECL char *(char *)
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char [20]
#        CursorKind.INTEGER_LITERAL int
#   tempnam CursorKind.FUNCTION_DECL char *(const char *, const char *)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __dir CursorKind.PARM_DECL const char *
#     __pfx CursorKind.PARM_DECL const char *
#   fflush CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fflush_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fopen CursorKind.FUNCTION_DECL FILE *(const char *, const char *)
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#     __filename CursorKind.PARM_DECL const char *restrict
#     __modes CursorKind.PARM_DECL const char *restrict
#   freopen CursorKind.FUNCTION_DECL FILE *(const char *restrict, const char *restrict, FILE *restrict)
#     FILE CursorKind.TYPE_REF FILE
#     __filename CursorKind.PARM_DECL const char *restrict
#     __modes CursorKind.PARM_DECL const char *restrict
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   fdopen CursorKind.FUNCTION_DECL FILE *(int, const char *)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#     __fd CursorKind.PARM_DECL int
#     __modes CursorKind.PARM_DECL const char *
#   fmemopen CursorKind.FUNCTION_DECL FILE *(void *, int, const char *)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#     __s CursorKind.PARM_DECL void *
#     __len CursorKind.PARM_DECL int
#     __modes CursorKind.PARM_DECL const char *
#   open_memstream CursorKind.FUNCTION_DECL FILE *(char **, int *)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#     __bufloc CursorKind.PARM_DECL char **
#     __sizeloc CursorKind.PARM_DECL int *
#   setbuf CursorKind.FUNCTION_DECL void (FILE *restrict, char *restrict)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __buf CursorKind.PARM_DECL char *restrict
#   setvbuf CursorKind.FUNCTION_DECL int (FILE *restrict, char *restrict, int, int)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __buf CursorKind.PARM_DECL char *restrict
#     __modes CursorKind.PARM_DECL int
#     __n CursorKind.PARM_DECL int
#   setbuffer CursorKind.FUNCTION_DECL void (FILE *restrict, char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __buf CursorKind.PARM_DECL char *restrict
#     __size CursorKind.PARM_DECL int
#   setlinebuf CursorKind.FUNCTION_DECL void (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fprintf CursorKind.FUNCTION_DECL int (FILE *, const char *, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#   printf CursorKind.FUNCTION_DECL int (const char *, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __format CursorKind.PARM_DECL const char *restrict
#   sprintf CursorKind.FUNCTION_DECL int (char *, const char *, ...)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#   vfprintf CursorKind.FUNCTION_DECL int (FILE *restrict, const char *restrict, int)
#     __s CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vprintf CursorKind.FUNCTION_DECL int (const char *restrict, int)
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vsprintf CursorKind.FUNCTION_DECL int (char *restrict, const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   snprintf CursorKind.FUNCTION_DECL int (char *restrict, int, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char *restrict
#     __maxlen CursorKind.PARM_DECL int
#     __format CursorKind.PARM_DECL const char *restrict
#   vsnprintf CursorKind.FUNCTION_DECL int (char *restrict, int, const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char *restrict
#     __maxlen CursorKind.PARM_DECL int
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vdprintf CursorKind.FUNCTION_DECL int (int, const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#     __fd CursorKind.PARM_DECL int
#     __fmt CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   dprintf CursorKind.FUNCTION_DECL int (int, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __fd CursorKind.PARM_DECL int
#     __fmt CursorKind.PARM_DECL const char *restrict
#   fscanf CursorKind.FUNCTION_DECL int (FILE *restrict, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#   scanf CursorKind.FUNCTION_DECL int (const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __format CursorKind.PARM_DECL const char *restrict
#   sscanf CursorKind.FUNCTION_DECL int (const char *restrict, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL const char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#   _Float32 CursorKind.TYPEDEF_DECL _Float32
#   _Float64 CursorKind.TYPEDEF_DECL _Float64
#   _Float32x CursorKind.TYPEDEF_DECL _Float32x
#   _Float64x CursorKind.TYPEDEF_DECL _Float64x
#   fscanf CursorKind.FUNCTION_DECL int (FILE *restrict, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __isoc99_fscanf CursorKind.ASM_LABEL_ATTR
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#   scanf CursorKind.FUNCTION_DECL int (const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __isoc99_scanf CursorKind.ASM_LABEL_ATTR
#     __format CursorKind.PARM_DECL const char *restrict
#   sscanf CursorKind.FUNCTION_DECL int (const char *restrict, const char *restrict, ...)
#      CursorKind.UNEXPOSED_ATTR
#     __isoc99_sscanf CursorKind.ASM_LABEL_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL const char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#   vfscanf CursorKind.FUNCTION_DECL int (FILE *restrict, const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vscanf CursorKind.FUNCTION_DECL int (const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vsscanf CursorKind.FUNCTION_DECL int (const char *restrict, const char *restrict, int)
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL const char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vfscanf CursorKind.FUNCTION_DECL int (FILE *restrict, const char *restrict, int)
#     __isoc99_vfscanf CursorKind.ASM_LABEL_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vscanf CursorKind.FUNCTION_DECL int (const char *restrict, int)
#     __isoc99_vscanf CursorKind.ASM_LABEL_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   vsscanf CursorKind.FUNCTION_DECL int (const char *restrict, const char *restrict, int)
#     __isoc99_vsscanf CursorKind.ASM_LABEL_ATTR
#      CursorKind.UNEXPOSED_ATTR
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL const char *restrict
#     __format CursorKind.PARM_DECL const char *restrict
#     __arg CursorKind.PARM_DECL int
#   fgetc CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   getc CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   getchar CursorKind.FUNCTION_DECL int (void)
#   getc_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   getchar_unlocked CursorKind.FUNCTION_DECL int (void)
#   fgetc_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fputc CursorKind.FUNCTION_DECL int (int, FILE *)
#     __c CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   putc CursorKind.FUNCTION_DECL int (int, FILE *)
#     __c CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   putchar CursorKind.FUNCTION_DECL int (int)
#     __c CursorKind.PARM_DECL int
#   fputc_unlocked CursorKind.FUNCTION_DECL int (int, FILE *)
#     __c CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   putc_unlocked CursorKind.FUNCTION_DECL int (int, FILE *)
#     __c CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   putchar_unlocked CursorKind.FUNCTION_DECL int (int)
#     __c CursorKind.PARM_DECL int
#   getw CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   putw CursorKind.FUNCTION_DECL int (int, FILE *)
#     __w CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fgets CursorKind.FUNCTION_DECL char *(char *restrict, int, FILE *restrict)
#     __s CursorKind.PARM_DECL char *restrict
#     __n CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   __getdelim CursorKind.FUNCTION_DECL __ssize_t (char **restrict, int *restrict, int, FILE *restrict)
#     __ssize_t CursorKind.TYPE_REF __ssize_t
#     __lineptr CursorKind.PARM_DECL char **restrict
#     __n CursorKind.PARM_DECL int *restrict
#     __delimiter CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   getdelim CursorKind.FUNCTION_DECL __ssize_t (char **restrict, int *restrict, int, FILE *restrict)
#     __ssize_t CursorKind.TYPE_REF __ssize_t
#     __lineptr CursorKind.PARM_DECL char **restrict
#     __n CursorKind.PARM_DECL int *restrict
#     __delimiter CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   getline CursorKind.FUNCTION_DECL __ssize_t (char **restrict, int *restrict, FILE *restrict)
#     __ssize_t CursorKind.TYPE_REF __ssize_t
#     __lineptr CursorKind.PARM_DECL char **restrict
#     __n CursorKind.PARM_DECL int *restrict
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   fputs CursorKind.FUNCTION_DECL int (const char *restrict, FILE *restrict)
#     __s CursorKind.PARM_DECL const char *restrict
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#   puts CursorKind.FUNCTION_DECL int (const char *)
#     __s CursorKind.PARM_DECL const char *
#   ungetc CursorKind.FUNCTION_DECL int (int, FILE *)
#     __c CursorKind.PARM_DECL int
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fread CursorKind.FUNCTION_DECL int (void *restrict, int, int, FILE *restrict)
#   fwrite CursorKind.FUNCTION_DECL int (const void *restrict, int, int, FILE *restrict)
#   fread_unlocked CursorKind.FUNCTION_DECL int (void *restrict, int, int, FILE *restrict)
#   fwrite_unlocked CursorKind.FUNCTION_DECL int (const void *restrict, int, int, FILE *restrict)
#   fseek CursorKind.FUNCTION_DECL int (FILE *, long, int)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#     __off CursorKind.PARM_DECL long
#     __whence CursorKind.PARM_DECL int
#   ftell CursorKind.FUNCTION_DECL long (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   rewind CursorKind.FUNCTION_DECL void (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fseeko CursorKind.FUNCTION_DECL int (FILE *, __off_t, int)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#     __off CursorKind.PARM_DECL __off_t
#       __off_t CursorKind.TYPE_REF __off_t
#     __whence CursorKind.PARM_DECL int
#   ftello CursorKind.FUNCTION_DECL __off_t (FILE *)
#     __off_t CursorKind.TYPE_REF __off_t
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fgetpos CursorKind.FUNCTION_DECL int (FILE *restrict, fpos_t *restrict)
#     __stream CursorKind.PARM_DECL FILE *restrict
#       FILE CursorKind.TYPE_REF FILE
#     __pos CursorKind.PARM_DECL fpos_t *restrict
#       fpos_t CursorKind.TYPE_REF fpos_t
#   fsetpos CursorKind.FUNCTION_DECL int (FILE *, const fpos_t *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#     __pos CursorKind.PARM_DECL const fpos_t *
#       fpos_t CursorKind.TYPE_REF fpos_t
#   clearerr CursorKind.FUNCTION_DECL void (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   feof CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   ferror CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   clearerr_unlocked CursorKind.FUNCTION_DECL void (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   feof_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   ferror_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   perror CursorKind.FUNCTION_DECL void (const char *)
#     __s CursorKind.PARM_DECL const char *
#   fileno CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   fileno_unlocked CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   pclose CursorKind.FUNCTION_DECL int (FILE *)
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   popen CursorKind.FUNCTION_DECL FILE *(const char *, const char *)
#      CursorKind.UNEXPOSED_ATTR
#     FILE CursorKind.TYPE_REF FILE
#     __command CursorKind.PARM_DECL const char *
#     __modes CursorKind.PARM_DECL const char *
#   ctermid CursorKind.FUNCTION_DECL char *(char *)
#      CursorKind.UNEXPOSED_ATTR
#     __s CursorKind.PARM_DECL char *
#   flockfile CursorKind.FUNCTION_DECL void (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   ftrylockfile CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   funlockfile CursorKind.FUNCTION_DECL void (FILE *)
#      CursorKind.UNEXPOSED_ATTR
#     __stream CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   __uflow CursorKind.FUNCTION_DECL int (FILE *)
#      CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#   __overflow CursorKind.FUNCTION_DECL int (FILE *, int)
#      CursorKind.PARM_DECL FILE *
#       FILE CursorKind.TYPE_REF FILE
#      CursorKind.PARM_DECL int
#   getSum CursorKind.FUNCTION_DECL void (int, int)
#     n1 CursorKind.PARM_DECL int
#     n2 CursorKind.PARM_DECL int
#      CursorKind.COMPOUND_STMT
#        CursorKind.DECL_STMT
#         sum CursorKind.VAR_DECL int
#            CursorKind.BINARY_OPERATOR int
#             n1 CursorKind.UNEXPOSED_EXPR int
#               n1 CursorKind.DECL_REF_EXPR int
#             n2 CursorKind.UNEXPOSED_EXPR int
#               n2 CursorKind.DECL_REF_EXPR int
#        CursorKind.RETURN_STMT
#         sum CursorKind.UNEXPOSED_EXPR void
#           sum CursorKind.UNEXPOSED_EXPR int
#             sum CursorKind.DECL_REF_EXPR int
#   main CursorKind.FUNCTION_DECL int ()
#      CursorKind.COMPOUND_STMT
#        CursorKind.DECL_STMT
#         a CursorKind.VAR_DECL int
#            CursorKind.INTEGER_LITERAL int
#         b CursorKind.VAR_DECL int
#            CursorKind.INTEGER_LITERAL int
#         x CursorKind.VAR_DECL int
#            CursorKind.INTEGER_LITERAL int
#        CursorKind.DECL_STMT
#         result CursorKind.VAR_DECL int
#            CursorKind.INTEGER_LITERAL int
#       getSum CursorKind.CALL_EXPR void
#         getSum CursorKind.UNEXPOSED_EXPR void (*)(int, int)
#           getSum CursorKind.DECL_REF_EXPR void (int, int)
#         a CursorKind.UNEXPOSED_EXPR int
#           a CursorKind.DECL_REF_EXPR int
#          CursorKind.INTEGER_LITERAL int
#        CursorKind.DECL_STMT
#         result CursorKind.VAR_DECL char []
#        CursorKind.DECL_STMT
#         test CursorKind.VAR_DECL int
#           justDoThis CursorKind.CALL_EXPR int
#             justDoThis CursorKind.UNEXPOSED_EXPR int (*)()
#               justDoThis CursorKind.DECL_REF_EXPR int ()
#             a CursorKind.UNEXPOSED_EXPR int
#               a CursorKind.DECL_REF_EXPR int
#             b CursorKind.UNEXPOSED_EXPR int
#               b CursorKind.DECL_REF_EXPR int
#       okayGood CursorKind.CALL_EXPR int
#         okayGood CursorKind.UNEXPOSED_EXPR int (*)()
#           okayGood CursorKind.DECL_REF_EXPR int ()
#         x CursorKind.UNEXPOSED_EXPR int
#           x CursorKind.DECL_REF_EXPR int
#          CursorKind.INTEGER_LITERAL int
#       printf CursorKind.CALL_EXPR int
#         printf CursorKind.UNEXPOSED_EXPR int (*)(const char *, ...)
#           printf CursorKind.DECL_REF_EXPR int (const char *, ...)
#          CursorKind.UNEXPOSED_EXPR const char *
#            CursorKind.UNEXPOSED_EXPR char *
#             "Sum is: %d" CursorKind.STRING_LITERAL char [11]
#         result CursorKind.UNEXPOSED_EXPR int
#           result CursorKind.DECL_REF_EXPR int
#        CursorKind.RETURN_STMT
#          CursorKind.INTEGER_LITERAL int

# %%
def get_function_params(root, function_name, result):
    
    for node in root.walk_preorder():
        try:
            """
            checking if AST node belongs to function declaration
            and its name is same as passed function_name
            """
            if node.kind == CursorKind.FUNCTION_DECL \
            and node.spelling == function_name:
                # loop through its children and only append details of parameter node
                for c in node.get_children():
                    if c.kind == CursorKind.PARM_DECL:
                        result.append({"name": c.spelling, 
                                       "data_type": c.type.spelling})
                return
        except ValueError as e:
            # print("Error:", e)
            pass

# %%
param_list = []
get_function_params(root_cursor, "getSum", param_list)
param_list
# Out:
# [{'name': 'n1', 'data_type': 'int'}, {'name': 'n2', 'data_type': 'int'}]

# %%
def get_called_functions(root, result):
    for node in root.walk_preorder():
        try:
            if node.kind == CursorKind.CALL_EXPR:
                # "location": node.extent
                current_function = {"name": node.spelling, "return_type": node.type.spelling, "args": []}

                for c in node.get_arguments():
                    current_arg = "".join([x.spelling for x in list(c.get_tokens())]) if len(list(c.get_tokens())) > 0 else c.spelling

                    if len(current_arg) >= 3 and current_arg.startswith('\"') and current_arg.endswith('\"'):
                        current_arg = '\"' + current_arg[1:-1].replace('\"', "\"\"") + '\"'

                    current_function["args"].append({"name": current_arg, "data_type": c.type.spelling, "cursor_kind": c.kind})
                    # current_function["args"].append({"name": c.spelling, "data_type": c.type.spelling, "cursor_kind": c.kind})
                    # print(node.location)

                current_param_list = []
                if len(current_function["args"]) == 2 and \
                    (current_function["args"][0]["data_type"] == current_function["args"][1]["data_type"]):
                    get_function_params(root, node.spelling, current_param_list)
                current_function["params"] = current_param_list

                result.append(current_function)

        except ValueError:
            pass

# %%
function_list = []
get_called_functions(root_cursor, function_list)
function_list
# Out:
# [{'name': 'getSum',
#   'return_type': 'void',
#   'args': [{'name': 'a',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR},
#    {'name': '7',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.INTEGER_LITERAL}],
#   'params': [{'name': 'n1', 'data_type': 'int'},
#    {'name': 'n2', 'data_type': 'int'}]},
#  {'name': 'justDoThis',
#   'return_type': 'int',
#   'args': [{'name': 'a',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR},
#    {'name': 'b',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR}],
#   'params': []},
#  {'name': 'okayGood',
#   'return_type': 'int',
#   'args': [{'name': 'x',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR},
#    {'name': '500',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.INTEGER_LITERAL}],
#   'params': []},
#  {'name': 'printf',
#   'return_type': 'int',
#   'args': [{'name': '"Sum is: %d"',
#     'data_type': 'const char *',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR},
#    {'name': 'result',
#     'data_type': 'int',
#     'cursor_kind': CursorKind.UNEXPOSED_EXPR}],
#   'params': []}]

# %%
for function in function_list:
        
        if len(function["args"]) == 2 and \
            (function["args"][0]["data_type"] == function["args"][1]["data_type"]) and \
            (function["args"][0]["name"] != function["args"][1]["name"]):
            
            positive_sample = [function["name"], function["args"][0]["name"], function["args"][1]["name"],
                              function["args"][0]["data_type"]]
            
            if(len(function["params"]) == 2):
                positive_sample.append(function["params"][0]["name"])
                positive_sample.append(function["params"][1]["name"])
            else:
                positive_sample.append("")
                positive_sample.append("")
            
            negative_sample = deepcopy(positive_sample)
            # swap
            negative_sample[1], negative_sample[2] = negative_sample[2], negative_sample[1]
            
            positive_sample.append(str(0))
            negative_sample.append(str(1))
            
            positive_sample = "\t".join(positive_sample)
            negative_sample = "\t".join(negative_sample)
            
            print(positive_sample)
            print(negative_sample)
# Out:
# getSum	a	7	int	n1	n2	0
# getSum	7	a	int	n1	n2	1
# justDoThis	a	b	int			0
# justDoThis	b	a	int			1
# okayGood	x	500	int			0
# okayGood	500	x	int			1

# %% [markdown]
# ---------
# ## Negative sample generation from all code snippets - Function args swap only
# ---------

# %%
def generate_function_args_swap_dataset(root_dir):
    total_files, total_samples = 0, 0
    global current_file
    
    with open("function_binary_args_swap_dataset.csv", 'a') as function_swap_samples:
        function_swap_samples.write("file\tfunction_name\targ1\targ2\targ_type\tparam1\tparam2\tlabels")
        
        for root, dirs, files in os.walk(root_dir):
                for file in files:
                    if file.endswith(".c"):
                        total_files += 1

                        file_path = os.path.join(root, file)
                        current_file = file_path
                            
                            with open(file_path, 'rb') as f:
                                
                                content = str(f.read())

                                if content.count("\\n") <= 10_000:
                                    
                                    try:
                                        start_cursor = index.parse(file_path).cursor

                                        function_list = []
                                        get_called_functions(start_cursor, function_list)

                                        for function in function_list:

                                            if len(function["args"]) == 2 and \
                                                (function["args"][0]["data_type"] == function["args"][1]["data_type"]) and \
                                                (function["args"][0]["name"] != function["args"][1]["name"]) and \
                                                (len(function["args"][0]["name"]) <= 100) and \
                                                (len(function["args"][1]["name"]) <= 100):

                                                positive_sample = [f.name.split("/AI/MinorProject/c-corpus/")[1], function["name"], function["args"][0]["name"], function["args"][1]["name"],
                                                                  function["args"][0]["data_type"]]

                                                if(len(function["params"]) == 2):
                                                    positive_sample.append(function["params"][0]["name"])
                                                    positive_sample.append(function["params"][1]["name"])
                                                else:
                                                    positive_sample.append("")
                                                    positive_sample.append("")

                                                negative_sample = deepcopy(positive_sample)
                                                # swap
                                                negative_sample[2], negative_sample[3] = negative_sample[3], negative_sample[2]

                                                positive_sample.append(str(0))
                                                negative_sample.append(str(1))

                                                positive_sample = "\t".join(positive_sample)
                                                negative_sample = "\t".join(negative_sample)

                                                function_swap_samples.write("\n" + positive_sample)
                                                function_swap_samples.write("\n" + negative_sample)
                                                
                                                total_samples += 1
                                                
                                    except:
                                        print("---Error occurred---")

                        current_file = file_path

                        if total_files % 1000 == 0:
                            print("Total files:", total_files, ",", "Total samples:", total_samples)

# %%
# def generate_function_args_swap_dataset(root_dir):
#     total_files, total_samples = 0, 0
#     global current_file
    
#     with open("function_binary_args_swap_dataset.csv", 'a') as function_swap_samples:
#         function_swap_samples.write("file\tfunction_name\targ1\targ2\targ_type\tparam1\tparam2\tlabels")
        
#         for root, dirs, files in os.walk(root_dir):
#                 for file in files:
#                     if file.endswith(".c"):
#                         total_files += 1

#                         file_path = os.path.join(root, file)
#                         current_file = file_path

#                         if total_files > 550_000:
                            
#                             with open(file_path, 'rb') as f:
#                                 # print(f.name)
#                                 # time.sleep(0.1)
                                
#                                 content = str(f.read())

#                                 if content.count("\\n") <= 10_000:
                                    
#                                     try:
#                                         start_cursor = index.parse(file_path).cursor

#                                         function_list = []
#                                         get_called_functions(start_cursor, function_list)

#                                         for function in function_list:

#                                             if len(function["args"]) == 2 and \
#                                                 (function["args"][0]["data_type"] == function["args"][1]["data_type"]) and \
#                                                 (function["args"][0]["name"] != function["args"][1]["name"]) and \
#                                                 (len(function["args"][0]["name"]) <= 100) and \
#                                                 (len(function["args"][1]["name"]) <= 100):

#                                                 positive_sample = [f.name.split("/AI/MinorProject/c-corpus/")[1], function["name"], function["args"][0]["name"], function["args"][1]["name"],
#                                                                   function["args"][0]["data_type"]]

#                                                 if(len(function["params"]) == 2):
#                                                     positive_sample.append(function["params"][0]["name"])
#                                                     positive_sample.append(function["params"][1]["name"])
#                                                 else:
#                                                     positive_sample.append("")
#                                                     positive_sample.append("")

#                                                 negative_sample = deepcopy(positive_sample)
#                                                 # swap
#                                                 negative_sample[2], negative_sample[3] = negative_sample[3], negative_sample[2]

#                                                 positive_sample.append(str(0))
#                                                 negative_sample.append(str(1))

#                                                 positive_sample = "\t".join(positive_sample)
#                                                 negative_sample = "\t".join(negative_sample)

#                                                 function_swap_samples.write("\n" + positive_sample)
#                                                 function_swap_samples.write("\n" + negative_sample)
                                                
#                                                 total_samples += 1
                                                
#                                     except:
#                                         print("---Error occurred---")

#                         current_file = file_path

#                         if total_files % 1000 == 0:
#                             print("Total files:", total_files, ",", "Total samples:", total_samples)

# %%
root_dir = '/home/dipu/Documents/AI/MinorProject/c-corpus/'

generate_function_args_swap_dataset(root_dir)
# Out:
# Total files: 1000 , Total samples: 0
# Total files: 2000 , Total samples: 0
# Total files: 3000 , Total samples: 0
# Total files: 4000 , Total samples: 0
# Total files: 5000 , Total samples: 0
# Total files: 6000 , Total samples: 0
# Total files: 7000 , Total samples: 0
# Total files: 8000 , Total samples: 0
# Total files: 9000 , Total samples: 0
# Total files: 10000 , Total samples: 0
# Total files: 11000 , Total samples: 0
# Total files: 12000 , Total samples: 0
# Total files: 13000 , Total samples: 0
# Total files: 14000 , Total samples: 0
# Total files: 15000 , Total samples: 0
# Total files: 16000 , Total samples: 0
# Total files: 17000 , Total samples: 0
# Total files: 18000 , Total samples: 0
# Total files: 19000 , Total samples: 0
# Total files: 20000 , Total samples: 0
# Total files: 21000 , Total samples: 0
# Total files: 22000 , Total samples: 0
# Total files: 23000 , Total samples: 0
# Total files: 24000 , Total samples: 0
# Total files: 25000 , Total samples: 0
# Total files: 26000 , Total samples: 0
# Total files: 27000 , Total samples: 0
# Total files: 28000 , Total samples: 0
# Total files: 29000 , Total samples: 0
# Total files: 30000 , Total samples: 0
# Total files: 31000 , Total samples: 0
# Total files: 32000 , Total samples: 0
# Total files: 33000 , Total samples: 0
# Total files: 34000 , Total samples: 0
# Total files: 35000 , Total samples: 0
# Total files: 36000 , Total samples: 0
# Total files: 37000 , Total samples: 0
# Total files: 38000 , Total samples: 0
# Total files: 548000 , Total samples: 0
# Total files: 549000 , Total samples: 0
# Total files: 550000 , Total samples: 0
# Total files: 551000 , Total samples: 397
# terminate called after throwing an instance of 'std::bad_alloc'
#   what():  std::bad_alloc
# libclang: crash detected during parsing: {
#   'source_filename' : '/home/dipu/Documents/AI/MinorProject/c-corpus/cleaned/gcc/gcc/testsuite/gcc.dg/large-size-array-4.c'
#   'command_line_args' : ['clang'],
#   'unsaved_files' : [],
#   'options' : 0,
# }
# ---Error occurred---
# terminate called recursively
# libclang: crash detected during parsing: {
#   'source_filename' : '/home/dipu/Documents/AI/MinorProject/c-corpus/cleaned/gcc/gcc/testsuite/gcc.dg/large-size-array-2.c'
#   'command_line_args' : ['clang'],
#   'unsaved_files' : [],
#   'options' : 0,
# }
# ---Error occurred---
# Total files: 552000 , Total samples: 689
# Total files: 553000 , Total samples: 966
# Total files: 554000 , Total samples: 1078
# Total files: 555000 , Total samples: 1445
# Total files: 556000 , Total samples: 2254
# Total files: 557000 , Total samples: 3028
# Total files: 558000 , Total samples: 6557
# Total files: 559000 , Total samples: 8721
# Total files: 560000 , Total samples: 10022
# Total files: 561000 , Total samples: 11339
# Total files: 562000 , Total samples: 12350
# Total files: 563000 , Total samples: 12802
# Total files: 564000 , Total samples: 14230
# Total files: 565000 , Total samples: 14658
# Total files: 566000 , Total samples: 15078
# Total files: 567000 , Total samples: 15402
# Total files: 568000 , Total samples: 17429
# Total files: 569000 , Total samples: 19212
# Total files: 570000 , Total samples: 20722
# Total files: 571000 , Total samples: 21503
# Total files: 572000 , Total samples: 22755
# Total files: 573000 , Total samples: 23648
# Total files: 574000 , Total samples: 23725
# Total files: 575000 , Total samples: 24219
# Total files: 576000 , Total samples: 25893
# Total files: 577000 , Total samples: 27177
# Total files: 578000 , Total samples: 28407
# Total files: 579000 , Total samples: 29487
# Total files: 580000 , Total samples: 31038
# Total files: 581000 , Total samples: 31504
# Total files: 582000 , Total samples: 31542
# Total files: 583000 , Total samples: 31668
# Total files: 584000 , Total samples: 32707
# Total files: 585000 , Total samples: 34306
# Total files: 586000 , Total samples: 35100
# Total files: 587000 , Total samples: 35903
# Total files: 588000 , Total samples: 36624
# Total files: 589000 , Total samples: 38444
# Total files: 590000 , Total samples: 38954
# Total files: 591000 , Total samples: 39634
# Total files: 592000 , Total samples: 40707
# Total files: 593000 , Total samples: 41645
# Total files: 594000 , Total samples: 44289
# Total files: 595000 , Total samples: 45986
# Total files: 596000 , Total samples: 47150
# Total files: 597000 , Total samples: 47934
# Total files: 598000 , Total samples: 48434
# Total files: 599000 , Total samples: 48908
# Total files: 600000 , Total samples: 49979
# Total files: 601000 , Total samples: 51359
# Total files: 602000 , Total samples: 51772
# Total files: 603000 , Total samples: 52287
# Total files: 604000 , Total samples: 53250
# Total files: 605000 , Total samples: 53617
# Total files: 606000 , Total samples: 54933
# Total files: 607000 , Total samples: 56031
# Total files: 608000 , Total samples: 57560
# Total files: 609000 , Total samples: 59683
# Total files: 610000 , Total samples: 61227
# Total files: 692000 , Total samples: 158332
# Total files: 693000 , Total samples: 159102
# Total files: 694000 , Total samples: 160688
# Total files: 695000 , Total samples: 161601
# Total files: 696000 , Total samples: 162785
# Total files: 697000 , Total samples: 162989
# Total files: 698000 , Total samples: 163539
# Total files: 699000 , Total samples: 164490
# Total files: 700000 , Total samples: 164609
# Total files: 701000 , Total samples: 165933
# Total files: 702000 , Total samples: 167055
# Total files: 703000 , Total samples: 167201
# Total files: 704000 , Total samples: 168489
# Total files: 705000 , Total samples: 170118
# Total files: 706000 , Total samples: 171744
# Total files: 707000 , Total samples: 174916
# Total files: 708000 , Total samples: 177528
# Total files: 709000 , Total samples: 178526
# Total files: 710000 , Total samples: 179402
# Total files: 711000 , Total samples: 181806
# Total files: 712000 , Total samples: 182218
# Total files: 713000 , Total samples: 183250
# Total files: 714000 , Total samples: 184375
# Total files: 715000 , Total samples: 184861
# Total files: 716000 , Total samples: 185435
# Total files: 717000 , Total samples: 185617
# Total files: 718000 , Total samples: 185991
# Total files: 719000 , Total samples: 186249
# Total files: 720000 , Total samples: 186257
# Total files: 721000 , Total samples: 187951
# Total files: 722000 , Total samples: 190049

# %%
# function_args_swap_new.csv
# 385222 samples including positive and negative
# 156000 total files evaluated

# function_args_swap_full.csv
# Total files: 147000 , Total samples: 205501

# function_binary_args_swap_dataset.csv
# Total files: 550000 , Total samples: 1369283

# %%
# current_file
323324 * 2
# Out:
# 646648

# %%
"abc\"de\"fg"[1:-1].replace('\"', "\"\"")

# %%
"abc".endswith("c")

# %%
"/home/dipu/Documents/AI/MinorProject/c-corpus/cleaned/meridian59/clientd3d/makepal.c".split("/AI/MinorProject/c-corpus/")[1]
# Out:
# 'cleaned/meridian59/clientd3d/makepal.c'

# %%
len('function_swap_samples.write("file\tfunction_name\targ1\targ2\targ_type\tparam1\tparam2\tlabels")')
# Out:
# 89

# %% [markdown]
# -----
# ## Data generation
# -----

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("function_binary_args_swap_dataset.csv", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_685064/58981139.py in <module>
# ----> 1 df = pd.read_csv("function_binary_args_swap_dataset.csv", sep="\t")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     579
#     580     with parser:
# --> 581         return parser.read(nrows)
#     582
#     583
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1251             nrows = validate_integer("nrows", nrows)
#    1252             try:
# -> 1253                 index, columns, col_dict = self._engine.read(nrows)
#    1254             except Exception:
#    1255                 self.close()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     223         try:
#     224             if self.low_memory:
# --> 225                 chunks = self._reader.read_low_memory(nrows)
#     226                 # destructive to chunks
#     227                 data = _concatenate_chunks(chunks)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 8 fields in line 765582, saw 10

# %%
with open("function_binary_args_swap_dataset.csv", "r") as f:
    content = f.readlines()
    s = {}
    
    for line in content:
        total = len(line.split("\t"))
        
        if total in s.keys():
            s[total] += 1
        else:
            s[total] = 1
        
        if(total == 16):
            print(line.split("\t"))
    print(s)
# Out:
# ['cleaned/cutter/test/cutter/test-cut-readable-differ.c', 'cut_diff_readable', '"', '', '  GNU LESSER GENERAL PUBLIC LICENSE\\n""""', '', '       Version 2.1, February 1999"', '"', '', '    GNU GENERAL PUBLIC LICENSE\\n""""', '', '       Version 2, June 1991"', 'char *', '', '', '0\n']
# ['cleaned/cutter/test/cutter/test-cut-readable-differ.c', 'cut_diff_readable', '"', '', '    GNU GENERAL PUBLIC LICENSE\\n""""', '', '       Version 2, June 1991"', '"', '', '  GNU LESSER GENERAL PUBLIC LICENSE\\n""""', '', '       Version 2.1, February 1999"', 'char *', '', '', '1\n']
# {8: 1750153, 9: 64, 3: 139, 2: 88, 5: 137, 6: 49, 4: 51, 1: 14, 10: 16, 12: 4, 16: 2}

# %%
with open("func_args_dataset_filtered.csv", "w") as write_file:
    write_file.write("file\tfunction_name\targ1\targ2\targ_type\tparam1\tparam2\tlabels\n")
    
    with open("function_binary_args_swap_dataset.csv", "r") as f:
        total, count = 0, 0
        content = f.readlines()

        for line in content:
            tokens = line.split("\t")

            if(len(tokens) == 8 and tokens[-1] == "0\n"):
                write_file.write(line)
                count += 1
                
            total += 1
                
        print(total, count)
# Out:
# 1750717 875075

# %%
# total: 1750716, filtered: 875075*2

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("func_args_dataset_filtered.csv", sep="\t")
df
# Out:
#                                                      file function_name  \
# 0                  cleaned/meridian59/clientd3d/makepal.c         fopen
# 1                  cleaned/meridian59/clientd3d/makepal.c         fopen
# 2                   cleaned/meridian59/clientd3d/cursor.c   MouseToRoom
# 3                  cleaned/meridian59/clientd3d/loadrsc.c       stricmp
# 4                     cleaned/meridian59/clientd3d/util.c        strcmp
# ...                                                   ...           ...
# 875070  cleaned/notepadthing/build/psycopg2/psycopg/ty...        strcmp
# 875071  cleaned/notepadthing/build/psycopg2/psycopg/co...        strcmp
# 875072  cleaned/notepadthing/build/psycopg2/psycopg/co...       Dprintf
# 875073  cleaned/notepadthing/build/psycopg2/psycopg/pq...       Dprintf
# 875074  cleaned/notepadthing/build/psycopg2/psycopg/pq...        strcmp
#
#                                                 arg1               arg2  \
# 0                                               file                  r
# 1                                            tempbuf                 wt
# 2                                                 &x                 &y
# 3                                          (char*)f1          (char*)f2
# 4                                              ext+1          extension
# ...                                              ...                ...
# 875070                                           str          -infinity
# 875071                                           off                scs
# 875072  conn_connect: server requires E'' quotes: %s  equote?"YES":"NO"
# 875073               pq_resolve_critical: error = %s                msg
# 875074                                         value            default
#
#             arg_type      param1   param2  labels
# 0       const char *  __filename  __modes       0
# 1       const char *  __filename  __modes       0
# 2              int *         NaN      NaN       0
# 3             char *         NaN      NaN       0
# 4       const char *         NaN      NaN       0
# ...              ...         ...      ...     ...
# 875070  const char *         NaN      NaN       0
# 875071  const char *        __s1     __s2       0
# 875072        char *         NaN      NaN       0
# 875073        char *         NaN      NaN       0
# 875074  const char *        __s1     __s2       0
#
# [875075 rows x 8 columns]

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
df
# Out:
#                                                      file       function_name  \
# 0                 cleaned/util-linux/term-utils/setterm.c              strcmp
# 1       cleaned/b2g-python/host/Python-2.7.3/Modules/c...              WRITE2
# 2                                       cleaned/ngp/ngp.c     display_entries
# 3       cleaned/msm7x30-3.4.x-naa/net/netfilter/xt_has...  hlist_add_head_rcu
# 4                     cleaned/lldpd/tests/check_marshal.c    ck_assert_str_eq
# ...                                                   ...                 ...
# 875070           cleaned/fvwm/modules/FvwmScript/script.c              AddCom
# 875071           cleaned/zfs-crypto/module/zfs/spa_misc.c             strpbrk
# 875072             cleaned/mplayer-ww/libaf/af_resample.c              av_gcd
# 875073  cleaned/sslcaudit/openssl-1.0.1b/crypto/x509v3...    ASN1_INTEGER_cmp
# 875074                          cleaned/pkgng/pkg/audit.c              calloc
#
#                    arg1                         arg2              arg_type  \
# 0          argv[argc-1]                       yellow          const char *
# 1                   '~'                          '}'                   int
# 2                 index                       cursor                 int *
# 3            &ent->node  &ht->hash[hash_dst(ht,dst)]      <dependent type>
# 4       destination->s3                     String 3                char *
# ...                 ...                          ...                   ...
# 875070               24                            2                   int
# 875071             name                           /@          const char *
# 875072               up                           dn               int64_t
# 875073            a_min                        a_max  const ASN1_INTEGER *
# 875074                1    sizeof(structaudit_entry)         unsigned long
#
#        param1      param2  labels
# 0        __s1        __s2       0
# 1         NaN         NaN       0
# 2       index      cursor       0
# 3         NaN         NaN       0
# 4         NaN         NaN       0
# ...       ...         ...     ...
# 875070   Type  NbLevelArg       0
# 875071    NaN         NaN       0
# 875072      a           b       0
# 875073      x           y       0
# 875074    NaN         NaN       0
#
# [875075 rows x 8 columns]

# %%
df.columns[1:-1]
# Out:
# Index(['function_name', 'arg1', 'arg2', 'arg_type', 'param1', 'param2'], dtype='object')

# %%
df.drop_duplicates(subset=df.columns[1:-1], ignore_index=True, inplace=True)
df
# Out:
#                                                      file  \
# 0                 cleaned/util-linux/term-utils/setterm.c
# 1       cleaned/b2g-python/host/Python-2.7.3/Modules/c...
# 2                                       cleaned/ngp/ngp.c
# 3       cleaned/msm7x30-3.4.x-naa/net/netfilter/xt_has...
# 4                     cleaned/lldpd/tests/check_marshal.c
# ...                                                   ...
# 270292  cleaned/opensplice/setup/wrappers/wincmd/ospl_...
# 270293              cleaned/fvwm/tests/hints/hints_test.c
# 270294              cleaned/libmate/libmate/mate-config.c
# 270295                           cleaned/tinc/src/tincd.c
# 270296           cleaned/fvwm/modules/FvwmScript/script.c
#
#                     function_name                arg1  \
# 0                          strcmp        argv[argc-1]
# 1                          WRITE2                 '~'
# 2                 display_entries               index
# 3              hlist_add_head_rcu          &ent->node
# 4                ck_assert_str_eq     destination->s3
# ...                           ...                 ...
# 270292                     addarg  -outputresource:%s
# 270293                 strcasecmp             argv[i]
# 270294  config_concat_dir_and_key         mate/config
# 270295                 strcasecmp              optarg
# 270296                     AddCom                  24
#
#                                arg2          arg_type   param1      param2  \
# 0                            yellow      const char *     __s1        __s2
# 1                               '}'               int      NaN         NaN
# 2                            cursor             int *    index      cursor
# 3       &ht->hash[hash_dst(ht,dst)]  <dependent type>      NaN         NaN
# 4                          String 3            char *      NaN         NaN
# ...                             ...               ...      ...         ...
# 270292                     &arg[16]            char *  pattern         val
# 270293                        modal      const char *     __s1        __s2
# 270294                     rel_file      const char *      dir         key
# 270295                          HUP      const char *     __s1        __s2
# 270296                            2               int     Type  NbLevelArg
#
#         labels
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 270292       0
# 270293       0
# 270294       0
# 270295       0
# 270296       0
#
# [270297 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.1, random_state=42)

df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train
# Out:
#                                                      file function_name  \
# 0                  cleaned/reconnoiter/src/stratcon_iep.c        calloc
# 1       cleaned/android-external-qemu/target-i386/help...        strcmp
# 2         cleaned/open-watcom/bld/clib/string/c/strtest.c        strcmp
# 3       cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...   punpckhwd_u
# 4       cleaned/qemu-devel-1.4.0/work/qemu-1.4.0/roms/...         peekb
# ...                                                   ...           ...
# 243262                    cleaned/showtime/src/showtime.c        strcmp
# 243263                            cleaned/socat/xioopts.c        Error1
# 243264  cleaned/dd-wrt/ar5315_microredboot/microredboo...         error
# 243265         cleaned/dd-wrt/src/router/libutils/utils.c        strcmp
# 243266  cleaned/gargoyle/package/ddns-gargoyle/src/ddn...   safe_strcmp
#
#                                    arg1              arg2          arg_type  \
# 0                                     1     sizeof(*stmt)     unsigned long
# 1                                  name  x86_defs[i].name      const char *
# 2                                  bufA            newBuf      const char *
# 3                                   s.v               t.v  <dependent type>
# 4                                  0x40              0x62               int
# ...                                 ...               ...               ...
# 243262                          argv[0]       --ffmpeglog      const char *
# 243263  getgrnam(\"%s\"): no such group             token            char *
# 243264       invalid --param option: %s               arg            char *
# 243265                           bridge            ifname      const char *
# 243266                      variable[0]    success_regexp            char *
#
#        param1 param2  labels
# 0         NaN    NaN       0
# 1        __s1   __s2       0
# 2        __s1   __s2       0
# 3         NaN    NaN       0
# 4         NaN    NaN       0
# ...       ...    ...     ...
# 243262   __s1   __s2       0
# 243263    NaN    NaN       0
# 243264    NaN    NaN       0
# 243265   __s1   __s2       0
# 243266    NaN    NaN       0
#
# [243267 rows x 8 columns]

# %%
df_test
# Out:
#                                                     file   function_name  \
# 0                          cleaned/tvheadend/src/utils.c          printf
# 1      cleaned/asuswrt-merlin/release/src/router/samb...          strcmp
# 2      cleaned/linux/drivers/media/video/hdpvr/hdpvr-...  list_move_tail
# 3       cleaned/unvanquished/src/tools/owmap/path_init.c       Q_stricmp
# 4                             cleaned/uwsgi/core/utils.c          strstr
# ...                                                  ...             ...
# 27025                cleaned/vsr/externals/gl2ps/gl2ps.c     gl2psPrintf
# 27026                       cleaned/bahamut/src/s_conf.c       DupString
# 27027                   cleaned/kmscon/src/uterm_input.c  shl_dlist_link
# 27028        cleaned/opensc/src/libopensc/card-openpgp.c          calloc
# 27029                   cleaned/ldmud/mudlib/dhrystone.c          Func_1
#
#                    arg1                  arg2          arg_type   param1  \
# 0                  %s:                    pfx      const char *      NaN
# 1                sidstr      sid_codes[i].sid      const char *      NaN
# 2       &buf->buff_list   &dev->rec_buff_list  <dependent type>      NaN
# 3                   arg                quake2            char *      NaN
# 4                   src                  what      const char *      NaN
# ...                 ...                   ...               ...      ...
# 27025         [] 0 %s\n                   str      const char *      NaN
# 27026  MeLine->admin[1]  new_MeLine->admin[1]  <dependent type>      NaN
# 27027   &input->devices            &dev->list  <dependent type>      NaN
# 27028                 1           sizeof*priv     unsigned long  __nmemb
# 27029          Ch_Index                   'C'               int       i1
#
#        param2  labels
# 0         NaN       0
# 1         NaN       0
# 2         NaN       0
# 3         NaN       0
# 4         NaN       0
# ...       ...     ...
# 27025     NaN       0
# 27026     NaN       0
# 27027     NaN       0
# 27028  __size       0
# 27029      i2       0
#
# [27030 rows x 8 columns]

# %%
print("Total:", len(df_train.index))

neg_train_array = []
count = 0

for index, row in df_train.iterrows():
    row["arg1"], row["arg2"] = row["arg2"], row["arg1"]
    row["labels"] = 1
    
    neg_train_array.append(row.values)
    
    count += 1
    if count % 25000 == 0:
        print(count)

df_train_neg = pd.DataFrame(neg_train_array, columns=df.columns)
df_train = pd.concat([df_train, df_train_neg])
df_train
# Out:
# Total: 243267
# 25000
# 50000
# 75000
# 100000
# 125000
# 150000
# 175000
# 200000
# 225000
#                                                      file function_name  \
# 0                  cleaned/reconnoiter/src/stratcon_iep.c        calloc
# 1       cleaned/android-external-qemu/target-i386/help...        strcmp
# 2         cleaned/open-watcom/bld/clib/string/c/strtest.c        strcmp
# 3       cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...   punpckhwd_u
# 4       cleaned/qemu-devel-1.4.0/work/qemu-1.4.0/roms/...         peekb
# ...                                                   ...           ...
# 243262                    cleaned/showtime/src/showtime.c        strcmp
# 243263                            cleaned/socat/xioopts.c        Error1
# 243264  cleaned/dd-wrt/ar5315_microredboot/microredboo...         error
# 243265         cleaned/dd-wrt/src/router/libutils/utils.c        strcmp
# 243266  cleaned/gargoyle/package/ddns-gargoyle/src/ddn...   safe_strcmp
#
#                   arg1                             arg2          arg_type  \
# 0                    1                    sizeof(*stmt)     unsigned long
# 1                 name                 x86_defs[i].name      const char *
# 2                 bufA                           newBuf      const char *
# 3                  s.v                              t.v  <dependent type>
# 4                 0x40                             0x62               int
# ...                ...                              ...               ...
# 243262     --ffmpeglog                          argv[0]      const char *
# 243263           token  getgrnam(\"%s\"): no such group            char *
# 243264             arg       invalid --param option: %s            char *
# 243265          ifname                           bridge      const char *
# 243266  success_regexp                      variable[0]            char *
#
#        param1 param2  labels
# 0         NaN    NaN       0
# 1        __s1   __s2       0
# 2        __s1   __s2       0
# 3         NaN    NaN       0
# 4         NaN    NaN       0
# ...       ...    ...     ...
# 243262   __s1   __s2       1
# 243263    NaN    NaN       1
# 243264    NaN    NaN       1
# 243265   __s1   __s2       1
# 243266    NaN    NaN       1
#
# [486534 rows x 8 columns]

# %%
print("Total:", len(df_test.index))

neg_test_array = []
count = 0

for index, row in df_test.iterrows():
    row["arg1"], row["arg2"] = row["arg2"], row["arg1"]
    row["labels"] = 1
    
    neg_test_array.append(row.values)
    
    count += 1
    if count % 25000 == 0:
        print(count)

df_test_neg = pd.DataFrame(neg_test_array, columns=df.columns)
df_test = pd.concat([df_test, df_test_neg])
df_test
# Out:
# Total: 27030
# 25000
#                                                     file   function_name  \
# 0                          cleaned/tvheadend/src/utils.c          printf
# 1      cleaned/asuswrt-merlin/release/src/router/samb...          strcmp
# 2      cleaned/linux/drivers/media/video/hdpvr/hdpvr-...  list_move_tail
# 3       cleaned/unvanquished/src/tools/owmap/path_init.c       Q_stricmp
# 4                             cleaned/uwsgi/core/utils.c          strstr
# ...                                                  ...             ...
# 27025                cleaned/vsr/externals/gl2ps/gl2ps.c     gl2psPrintf
# 27026                       cleaned/bahamut/src/s_conf.c       DupString
# 27027                   cleaned/kmscon/src/uterm_input.c  shl_dlist_link
# 27028        cleaned/opensc/src/libopensc/card-openpgp.c          calloc
# 27029                   cleaned/ldmud/mudlib/dhrystone.c          Func_1
#
#                        arg1                 arg2          arg_type   param1  \
# 0                      %s:                   pfx      const char *      NaN
# 1                    sidstr     sid_codes[i].sid      const char *      NaN
# 2           &buf->buff_list  &dev->rec_buff_list  <dependent type>      NaN
# 3                       arg               quake2            char *      NaN
# 4                       src                 what      const char *      NaN
# ...                     ...                  ...               ...      ...
# 27025                   str            [] 0 %s\n      const char *      NaN
# 27026  new_MeLine->admin[1]     MeLine->admin[1]  <dependent type>      NaN
# 27027            &dev->list      &input->devices  <dependent type>      NaN
# 27028           sizeof*priv                    1     unsigned long  __nmemb
# 27029                   'C'             Ch_Index               int       i1
#
#        param2  labels
# 0         NaN       0
# 1         NaN       0
# 2         NaN       0
# 3         NaN       0
# 4         NaN       0
# ...       ...     ...
# 27025     NaN       1
# 27026     NaN       1
# 27027     NaN       1
# 27028  __size       1
# 27029      i2       1
#
# [54060 rows x 8 columns]

# %%
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)
df_train
# Out:
#                                                      file     function_name  \
# 0                             cleaned/collectd/src/amqp.c              INFO
# 1                                  cleaned/bspwm/events.c               MAX
# 2             cleaned/newlib/newlib/libm/math/sf_signif.c  __ieee754_scalbf
# 3       cleaned/dd-wrt/src/router/proftpd/contrib/mod_...             crypt
# 4          cleaned/tpm-tools/src/tpm_mgmt/tpm_clearable.c          logDebug
# ...                                                   ...               ...
# 486529             cleaned/libgit2/tests-clar/core/path.c     check_dirname
# 486530  cleaned/asuswrt-merlin/release/src-rt/linux/li...              outw
# 486531                 cleaned/zif/libzif/zif-self-test.c   zif_compare_evr
# 486532                     cleaned/fvwm/fvwm/windowlist.c         StrEquals
# 486533               cleaned/mlt/src/modules/lumas/luma.c            strcmp
#
#                                             arg1  \
# 0                                    conf->queue
# 1                                              1
# 2                              (float)-ilogbf(x)
# 3                                     ciphertext
# 4       _("Requested to disable: %s ability.\n")
# ...                                          ...
# 486529                                         /
# 486530                            ioaddr+IO_PORT
# 486531                                       0.1
# 486532                                       tok
# 486533                                 argv[arg]
#
#                                       arg2      arg_type param1 param2  labels
# 0       amqp plugin: Created queue \"%s\".        char *    NaN    NaN       1
# 1                                        h           int    NaN    NaN       0
# 2                                        x        double    NaN    NaN       1
# 3                                plaintext  const char *    NaN    NaN       1
# 4                         _(flags[i].name)           int    NaN    NaN       0
# ...                                    ...           ...    ...    ...     ...
# 486529                                /usr  const char *      A      B       1
# 486530                           eaddrs[1]           int    NaN    NaN       1
# 486531                             0:0.1-1        char *    NaN    NaN       0
# 486532                          NoDeskSort        char *    NaN    NaN       0
# 486533                              -rband  const char *   __s1   __s2       0
#
# [486534 rows x 8 columns]

# %%
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True)
df_test
# Out:
#                                                     file function_name  \
# 0                           cleaned/powerswitch-os/vga.c          outb
# 1      cleaned/platform_external/icu4c/test/cintltst/...        strcmp
# 2                       cleaned/gnushogi/xshogi/xshogi.c        strcmp
# 3      cleaned/asuswrt-merlin/release/src/router/samb...         DEBUG
# 4               cleaned/tos-sfsu-fall2012/kernel/shell.c    is_command
# ...                                                  ...           ...
# 54055      cleaned/lucy/clownfish/compiler/src/CFCType.c        strcmp
# 54056  cleaned/opensplice/src/services/ddsi2/code/nn_...    avl_delete
# 54057                cleaned/marss/qemu/hw/etraxfs_pic.c  qemu_set_irq
# 54058      cleaned/sane-backends/backend/genesys_gl847.c        SETREG
# 54059                cleaned/drone/lib/ffmpeg/ffserver.c    strcasecmp
#
#                           arg1  \
# 0                 mode13[2][i]
# 1                 subBundleKey
# 2                         name
# 3                            0
# 4                      command
# ...                        ...
# 54055                specifier
# 54056  onode_from_node(tree,n)
# 54057      !!fs->regs[R_R_NMI]
# 54058                     0x9d
# 54059                      cmd
#
#                                                     arg2          arg_type  \
# 0                                                  0x3cf               int
# 1                                       availableFormats      const char *
# 2                                                    Yes      const char *
# 3      ("%s: bad validation_level value %d.\n",fn,(in...               int
# 4                                                   pong            char *
# ...                                                  ...               ...
# 54055                                            int64_t      const char *
# 54056                                               tree            void *
# 54057                                     fs->parent_nmi  <dependent type>
# 54058                                               0x06               int
# 54059                                        BindAddress      const char *
#
#       param1 param2  labels
# 0        NaN    NaN       1
# 1        NaN    NaN       0
# 2       __s1   __s2       0
# 3        NaN    NaN       0
# 4         s1     s2       0
# ...      ...    ...     ...
# 54055   __s1   __s2       0
# 54056  vtree  vnode       1
# 54057    NaN    NaN       1
# 54058    NaN    NaN       0
# 54059    NaN    NaN       0
#
# [54060 rows x 8 columns]

# %%
df_train.to_csv("func_args_dataset_filtered_train.csv", sep="\t", index=False)
df_test.to_csv("func_args_dataset_filtered_test.csv", sep="\t", index=False)

# %%
pd.read_csv("func_args_dataset_filtered_train.csv", sep="\t")
# Out:
#                                                      file     function_name  \
# 0                             cleaned/collectd/src/amqp.c              INFO
# 1                                  cleaned/bspwm/events.c               MAX
# 2             cleaned/newlib/newlib/libm/math/sf_signif.c  __ieee754_scalbf
# 3       cleaned/dd-wrt/src/router/proftpd/contrib/mod_...             crypt
# 4          cleaned/tpm-tools/src/tpm_mgmt/tpm_clearable.c          logDebug
# ...                                                   ...               ...
# 486529             cleaned/libgit2/tests-clar/core/path.c     check_dirname
# 486530  cleaned/asuswrt-merlin/release/src-rt/linux/li...              outw
# 486531                 cleaned/zif/libzif/zif-self-test.c   zif_compare_evr
# 486532                     cleaned/fvwm/fvwm/windowlist.c         StrEquals
# 486533               cleaned/mlt/src/modules/lumas/luma.c            strcmp
#
#                                             arg1  \
# 0                                    conf->queue
# 1                                              1
# 2                              (float)-ilogbf(x)
# 3                                     ciphertext
# 4       _("Requested to disable: %s ability.\n")
# ...                                          ...
# 486529                                         /
# 486530                            ioaddr+IO_PORT
# 486531                                       0.1
# 486532                                       tok
# 486533                                 argv[arg]
#
#                                       arg2      arg_type param1 param2  labels
# 0       amqp plugin: Created queue \"%s\".        char *    NaN    NaN       1
# 1                                        h           int    NaN    NaN       0
# 2                                        x        double    NaN    NaN       1
# 3                                plaintext  const char *    NaN    NaN       1
# 4                         _(flags[i].name)           int    NaN    NaN       0
# ...                                    ...           ...    ...    ...     ...
# 486529                                /usr  const char *      A      B       1
# 486530                           eaddrs[1]           int    NaN    NaN       1
# 486531                             0:0.1-1        char *    NaN    NaN       0
# 486532                          NoDeskSort        char *    NaN    NaN       0
# 486533                              -rband  const char *   __s1   __s2       0
#
# [486534 rows x 8 columns]

# %%
pd.read_csv("func_args_dataset_filtered_test.csv", sep="\t")
# Out:
#                                                     file function_name  \
# 0                           cleaned/powerswitch-os/vga.c          outb
# 1      cleaned/platform_external/icu4c/test/cintltst/...        strcmp
# 2                       cleaned/gnushogi/xshogi/xshogi.c        strcmp
# 3      cleaned/asuswrt-merlin/release/src/router/samb...         DEBUG
# 4               cleaned/tos-sfsu-fall2012/kernel/shell.c    is_command
# ...                                                  ...           ...
# 54055      cleaned/lucy/clownfish/compiler/src/CFCType.c        strcmp
# 54056  cleaned/opensplice/src/services/ddsi2/code/nn_...    avl_delete
# 54057                cleaned/marss/qemu/hw/etraxfs_pic.c  qemu_set_irq
# 54058      cleaned/sane-backends/backend/genesys_gl847.c        SETREG
# 54059                cleaned/drone/lib/ffmpeg/ffserver.c    strcasecmp
#
#                           arg1  \
# 0                 mode13[2][i]
# 1                 subBundleKey
# 2                         name
# 3                            0
# 4                      command
# ...                        ...
# 54055                specifier
# 54056  onode_from_node(tree,n)
# 54057      !!fs->regs[R_R_NMI]
# 54058                     0x9d
# 54059                      cmd
#
#                                                     arg2          arg_type  \
# 0                                                  0x3cf               int
# 1                                       availableFormats      const char *
# 2                                                    Yes      const char *
# 3      ("%s: bad validation_level value %d.\n",fn,(in...               int
# 4                                                   pong            char *
# ...                                                  ...               ...
# 54055                                            int64_t      const char *
# 54056                                               tree            void *
# 54057                                     fs->parent_nmi  <dependent type>
# 54058                                               0x06               int
# 54059                                        BindAddress      const char *
#
#       param1 param2  labels
# 0        NaN    NaN       1
# 1        NaN    NaN       0
# 2       __s1   __s2       0
# 3        NaN    NaN       0
# 4         s1     s2       0
# ...      ...    ...     ...
# 54055   __s1   __s2       0
# 54056  vtree  vnode       1
# 54057    NaN    NaN       1
# 54058    NaN    NaN       0
# 54059    NaN    NaN       0
#
# [54060 rows x 8 columns]
