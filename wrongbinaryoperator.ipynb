# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.read_csv("/kaggle/input/wrong-binary-operator-data/wrong_binary_operator_dataset_filtered.csv", sep="\t")
df
# Out:
#                                                       file              left  \
# 0                        cleaned/meridian59/club/archive.c  extraction_error
# 1                        cleaned/meridian59/club/archive.c  extraction_error
# 2                           cleaned/meridian59/club/util.c             index
# 3                           cleaned/meridian59/club/util.c         (index+1)
# 4                           cleaned/meridian59/club/util.c             index
# ...                                                    ...               ...
# 6854849  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 6854850  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 6854851  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 6854852  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 6854853  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
#
#         operator        right type_left type_right           parent  \
# 0              =            0       int        int    COMPOUND_STMT
# 1             ==            0       int        int          IF_STMT
# 2              =  (index+1)%4       int        int    COMPOUND_STMT
# 3              %            4       int        int  BINARY_OPERATOR
# 4              +            1       int        int       PAREN_EXPR
# ...          ...          ...       ...        ...              ...
# 6854849        =           -1       int        int          IF_STMT
# 6854850        =            0       int        int    COMPOUND_STMT
# 6854851        =           -1       int        int    COMPOUND_STMT
# 6854852        =           -1       int        int    COMPOUND_STMT
# 6854853       ==           -1       int        int          IF_STMT
#
#              grandparent  complex_operand  start_line  start_column  end_line  \
# 0             WHILE_STMT            False          46             7        46
# 1          COMPOUND_STMT            False          53            11        53
# 2          FUNCTION_DECL             True          75             4        75
# 3          COMPOUND_STMT             True          75            12        75
# 4        BINARY_OPERATOR            False          75            13        75
# ...                  ...              ...         ...           ...       ...
# 6854849    COMPOUND_STMT            False        1465            31      1465
# 6854850          IF_STMT            False        1472            44      1472
# 6854851      SWITCH_STMT            False        1480             9      1480
# 6854852      SWITCH_STMT            False        1487             9      1487
# 6854853    COMPOUND_STMT            False        1496            13      1496
#
#          end_column  labels
# 0                27       0
# 1                32       0
# 2                27       0
# 3                27       0
# 4                22       0
# ...             ...     ...
# 6854849          38       0
# 6854850          50       0
# 6854851          16       0
# 6854852          16       0
# 6854853          21       0
#
# [6854854 rows x 14 columns]

# %%
df.columns[1:-6]
# Out:
# Index(['left', 'operator', 'right', 'type_left', 'type_right', 'parent',
#        'grandparent'],
#       dtype='object')

# %%
df.drop_duplicates(subset=df.columns[1:-6], ignore_index=True, inplace=True)
df
# Out:
#                                                       file              left  \
# 0                        cleaned/meridian59/club/archive.c  extraction_error
# 1                        cleaned/meridian59/club/archive.c  extraction_error
# 2                           cleaned/meridian59/club/util.c             index
# 3                           cleaned/meridian59/club/util.c         (index+1)
# 4                           cleaned/meridian59/club/util.c             index
# ...                                                    ...               ...
# 1587091  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 1587092  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 1587093  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 1587094  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
# 1587095  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
#
#         operator        right type_left type_right           parent  \
# 0              =            0       int        int    COMPOUND_STMT
# 1             ==            0       int        int          IF_STMT
# 2              =  (index+1)%4       int        int    COMPOUND_STMT
# 3              %            4       int        int  BINARY_OPERATOR
# 4              +            1       int        int       PAREN_EXPR
# ...          ...          ...       ...        ...              ...
# 1587091        =            1       int        int    COMPOUND_STMT
# 1587092        =           -1       int        int          IF_STMT
# 1587093        =            0       int        int    COMPOUND_STMT
# 1587094        =           -1       int        int    COMPOUND_STMT
# 1587095       ==           -1       int        int          IF_STMT
#
#              grandparent  complex_operand  start_line  start_column  end_line  \
# 0             WHILE_STMT            False          46             7        46
# 1          COMPOUND_STMT            False          53            11        53
# 2          FUNCTION_DECL             True          75             4        75
# 3          COMPOUND_STMT             True          75            12        75
# 4        BINARY_OPERATOR            False          75            13        75
# ...                  ...              ...         ...           ...       ...
# 1587091      SWITCH_STMT            False        1448             9      1448
# 1587092    COMPOUND_STMT            False        1456            31      1456
# 1587093          IF_STMT            False        1472            44      1472
# 1587094      SWITCH_STMT            False        1480             9      1480
# 1587095    COMPOUND_STMT            False        1496            13      1496
#
#          end_column  labels
# 0                27       0
# 1                32       0
# 2                27       0
# 3                27       0
# 4                22       0
# ...             ...     ...
# 1587091          15       0
# 1587092          38       0
# 1587093          50       0
# 1587094          16       0
# 1587095          21       0
#
# [1587096 rows x 14 columns]

# %%
df = df[df["complex_operand"] == False]
df
# Out:
#                                                       file  \
# 0                        cleaned/meridian59/club/archive.c
# 1                        cleaned/meridian59/club/archive.c
# 4                           cleaned/meridian59/club/util.c
# 5                           cleaned/meridian59/club/util.c
# 6                       cleaned/meridian59/club/transfer.c
# ...                                                    ...
# 1587091  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587092  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587093  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587094  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587095  cleaned/notepadthing/build/psycopg2/psycopg/pq...
#
#                              left operator right type_left type_right  \
# 0                extraction_error        =     0       int        int
# 1                extraction_error       ==     0       int        int
# 4                           index        +     1       int        int
# 5        szLoadedString[index][0]        =     0      char       char
# 6                         outfile        <     0       int        int
# ...                           ...      ...   ...       ...        ...
# 1587091                        ex        =     1       int        int
# 1587092                        ex        =    -1       int        int
# 1587093                        ex        =     0       int        int
# 1587094                        ex        =    -1       int        int
# 1587095                        ex       ==    -1       int        int
#
#                 parent      grandparent  complex_operand  start_line  \
# 0        COMPOUND_STMT       WHILE_STMT            False          46
# 1              IF_STMT    COMPOUND_STMT            False          53
# 4           PAREN_EXPR  BINARY_OPERATOR            False          75
# 5        COMPOUND_STMT    FUNCTION_DECL            False          77
# 6              IF_STMT    COMPOUND_STMT            False         101
# ...                ...              ...              ...         ...
# 1587091  COMPOUND_STMT      SWITCH_STMT            False        1448
# 1587092        IF_STMT    COMPOUND_STMT            False        1456
# 1587093  COMPOUND_STMT          IF_STMT            False        1472
# 1587094  COMPOUND_STMT      SWITCH_STMT            False        1480
# 1587095        IF_STMT    COMPOUND_STMT            False        1496
#
#          start_column  end_line  end_column  labels
# 0                   7        46          27       0
# 1                  11        53          32       0
# 4                  13        75          22       0
# 5                   4        77          32       0
# 6                   8       101          19       0
# ...               ...       ...         ...     ...
# 1587091             9      1448          15       0
# 1587092            31      1456          38       0
# 1587093            44      1472          50       0
# 1587094             9      1480          16       0
# 1587095            13      1496          21       0
#
# [1253796 rows x 14 columns]

# %%
df = df.drop(columns=["complex_operand"])
df
# Out:
#                                                       file  \
# 0                        cleaned/meridian59/club/archive.c
# 1                        cleaned/meridian59/club/archive.c
# 4                           cleaned/meridian59/club/util.c
# 5                           cleaned/meridian59/club/util.c
# 6                       cleaned/meridian59/club/transfer.c
# ...                                                    ...
# 1587091  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587092  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587093  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587094  cleaned/notepadthing/build/psycopg2/psycopg/pq...
# 1587095  cleaned/notepadthing/build/psycopg2/psycopg/pq...
#
#                              left operator right type_left type_right  \
# 0                extraction_error        =     0       int        int
# 1                extraction_error       ==     0       int        int
# 4                           index        +     1       int        int
# 5        szLoadedString[index][0]        =     0      char       char
# 6                         outfile        <     0       int        int
# ...                           ...      ...   ...       ...        ...
# 1587091                        ex        =     1       int        int
# 1587092                        ex        =    -1       int        int
# 1587093                        ex        =     0       int        int
# 1587094                        ex        =    -1       int        int
# 1587095                        ex       ==    -1       int        int
#
#                 parent      grandparent  start_line  start_column  end_line  \
# 0        COMPOUND_STMT       WHILE_STMT          46             7        46
# 1              IF_STMT    COMPOUND_STMT          53            11        53
# 4           PAREN_EXPR  BINARY_OPERATOR          75            13        75
# 5        COMPOUND_STMT    FUNCTION_DECL          77             4        77
# 6              IF_STMT    COMPOUND_STMT         101             8       101
# ...                ...              ...         ...           ...       ...
# 1587091  COMPOUND_STMT      SWITCH_STMT        1448             9      1448
# 1587092        IF_STMT    COMPOUND_STMT        1456            31      1456
# 1587093  COMPOUND_STMT          IF_STMT        1472            44      1472
# 1587094  COMPOUND_STMT      SWITCH_STMT        1480             9      1480
# 1587095        IF_STMT    COMPOUND_STMT        1496            13      1496
#
#          end_column  labels
# 0                27       0
# 1                32       0
# 4                22       0
# 5                32       0
# 6                19       0
# ...             ...     ...
# 1587091          15       0
# 1587092          38       0
# 1587093          50       0
# 1587094          16       0
# 1587095          21       0
#
# [1253796 rows x 13 columns]

# %%
operator_count = {}

for index, row in df.iterrows():
    if(row["operator"] in operator_count.keys()):
        operator_count[row["operator"]] += 1
    else:
        operator_count[row["operator"]] = 1
        
print(operand_count)
# Out:
# {'=': 693413, '==': 109138, '+': 61795, '<': 67109, '*': 54360, '/': 18080, '|': 2813, '<<': 12254, '-': 47401, '>=': 20350, '!=': 47374, '<=': 16804, '&': 24290, '&&': 13265, '%': 4598, '>': 38016, '>>': 10280, '^': 1419, ',': 2832, '||': 7776, '/* for backward compatibility */': 1, '#': 43, '/* lwm -> sync. */': 1, 'static': 5, '/* Wait for video */': 1, '/*par->CR67*/': 1, ')': 291, 'K': 4, ' */': 2, '/* per-port power switching */': 1, '/* All ports power at once */': 1, '/* pad */': 3, '/* trailing null */': 1, '/* 1st signature byte */': 1, '/* string type byte */': 1, '/* level */': 3, '/* skip . and .. */': 1, 'to': 9, '/* fort. */': 1, '/* bb 5 */': 1, 'OP': 1, '/* { dg-warning "width of integer|traditional C rejects" } */': 1, '/* { dg-bogus "as unsigned due to prototype" } */': 3, '/* { dg-warning "as signed due to prototype" } */': 3, 'plus': 1, '\xa0': 1, '/* Bytes per sample. */': 1, '/*COLOR_INFO*/': 1, '/* "api_sig" */': 1, '/* handling+file offset+SP+newline */': 1, 'bitand': 1, ':': 1, '// for the indent spaces': 1, '// trailing spaces to add': 1, '/* 0x0 gpio_oe (state set by GPIO_OEREG) */': 2, '/* byte      SSH_MSG_USERAUTH_REQUEST */': 1, '/* byte      SSH_MSG_USERAUTH_INFO_RESPONSE */': 1, '/*&& AFS_NFSXLATORREQ(acred) */': 1, '/* old GNU */': 2, 'int': 3, '/* includes space for NUL */': 1, '/*CTRL-D*/': 1, '/* Zap caller if no caller id. */': 1, '/* Ethernet MTU */': 1, '/* Avoid to use the PPP interface */': 1, '/* Size of each temporary Tx/Rx buffer.*/': 1, '/* alternative branch needs testing */': 1, '/*+1*/': 1, '// for config files': 1, '/* INTL: digit */': 1, '/* not resuming from suspend */': 1, '/* RFC1001 len field */': 1, '/* PRUint16 length */': 1, '/* "tftp://xxx.xxx.xxx.xxx/" */': 1, '/* rss */': 1, '// send stop if nonzero': 1, '/*RAM*/': 1, '/* regular profile */': 1, '/* not invisible */': 1, 'object': 3, '/* = uu_xlat_native[i+0x40] */': 1, 'CRLF_CRLF': 1, '/*SOH*/': 1, '/*SCRATCHSEG*/': 1, '/* 0101 */': 1, '/* charset */': 1, '// Words that start with "uni" aren\'t treated like vowels; e.g., "a" unicorn.': 1}

# %%
{k: v for k, v in sorted(operator_count.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'=': 693413,
#  '==': 109138,
#  '<': 67109,
#  '+': 61795,
#  '*': 54360,
#  '-': 47401,
#  '!=': 47374,
#  '>': 38016,
#  '&': 24290,
#  '>=': 20350,
#  '/': 18080,
#  '<=': 16804,
#  '&&': 13265,
#  '<<': 12254,
#  '>>': 10280,
#  '||': 7776,
#  '%': 4598,
#  ',': 2832,
#  '|': 2813,
#  '^': 1419,
#  ')': 291,
#  '#': 43,
#  'to': 9,
#  'static': 5,
#  'K': 4,
#  '/* pad */': 3,
#  '/* level */': 3,
#  '/* { dg-bogus "as unsigned due to prototype" } */': 3,
#  '/* { dg-warning "as signed due to prototype" } */': 3,
#  'int': 3,
#  'object': 3,
#  ' */': 2,
#  '/* 0x0 gpio_oe (state set by GPIO_OEREG) */': 2,
#  '/* old GNU */': 2,
#  '/* for backward compatibility */': 1,
#  '/* lwm -> sync. */': 1,
#  '/* Wait for video */': 1,
#  '/*par->CR67*/': 1,
#  '/* per-port power switching */': 1,
#  '/* All ports power at once */': 1,
#  '/* trailing null */': 1,
#  '/* 1st signature byte */': 1,
#  '/* string type byte */': 1,
#  '/* skip . and .. */': 1,
#  '/* fort. */': 1,
#  '/* bb 5 */': 1,
#  'OP': 1,
#  '/* { dg-warning "width of integer|traditional C rejects" } */': 1,
#  'plus': 1,
#  '\xa0': 1,
#  '/* Bytes per sample. */': 1,
#  '/*COLOR_INFO*/': 1,
#  '/* "api_sig" */': 1,
#  '/* handling+file offset+SP+newline */': 1,
#  'bitand': 1,
#  ':': 1,
#  '// for the indent spaces': 1,
#  '// trailing spaces to add': 1,
#  '/* byte      SSH_MSG_USERAUTH_REQUEST */': 1,
#  '/* byte      SSH_MSG_USERAUTH_INFO_RESPONSE */': 1,
#  '/*&& AFS_NFSXLATORREQ(acred) */': 1,
#  '/* includes space for NUL */': 1,
#  '/*CTRL-D*/': 1,
#  '/* Zap caller if no caller id. */': 1,
#  '/* Ethernet MTU */': 1,
#  '/* Avoid to use the PPP interface */': 1,
#  '/* Size of each temporary Tx/Rx buffer.*/': 1,
#  '/* alternative branch needs testing */': 1,
#  '/*+1*/': 1,
#  '// for config files': 1,
#  '/* INTL: digit */': 1,
#  '/* not resuming from suspend */': 1,
#  '/* RFC1001 len field */': 1,
#  '/* PRUint16 length */': 1,
#  '/* "tftp://xxx.xxx.xxx.xxx/" */': 1,
#  '/* rss */': 1,
#  '// send stop if nonzero': 1,
#  '/*RAM*/': 1,
#  '/* regular profile */': 1,
#  '/* not invisible */': 1,
#  '/* = uu_xlat_native[i+0x40] */': 1,
#  'CRLF_CRLF': 1,
#  '/*SOH*/': 1,
#  '/*SCRATCHSEG*/': 1,
#  '/* 0101 */': 1,
#  '/* charset */': 1,
#  '// Words that start with "uni" aren\'t treated like vowels; e.g., "a" unicorn.': 1}

# %%
swappable_operator = {
    '==': ['>', '<', '!=', '>=', '<=', '='],
    '<': ['>', '==', '!=', '>=', '<=', '<<', '^', '>>'],
    '+': ['-', '*', '/', '%', '+='],
    '*': ['+', '-', '/', '%', '*='],
    '-': ['+', '*', '/', '%', '-='],
    '!=': ['>', '<', '==', '>=', '<=', '='],
    '>': ['==', '<', '!=', '>=', '<=', '<<', '^', '>>'],
    '&': ['|', '^', '<<', '>>', '&&', '||'],
    '>=': ['>', '<', '!=', '==', '<=', '<<', '^', '>>'],
    '/': ['+', '-', '*', '%', '/='],
    '<=': ['>', '<', '!=', '>=', '==', '<<', '^', '>>'],
    '&&': ['||', '&', '|'],
    '<<': ['|', '&', '^', '>>', '&&', '||', '<=', '<'],
    '>>': ['|', '&', '^', '<<', '&&', '||', '>=', '>'],
    '||': ['&&', '|', '&', '/'],
    '%': ['+', '-', '*', '/', '<', '>', '>=', '<=', '!=', '%='],
    '|': ['&', '^', '<<', '>>', '&&', '||', '/'],
    '^': ['|', '&', '<<', '>>', '&&', '||', '<', '>']
}

# %%
df = df.loc[(~df.operator.isin([",", "="]))]
df = df.reset_index(drop=True)
df
# Out:
#                                                      file              left  \
# 0                       cleaned/meridian59/club/archive.c  extraction_error
# 1                          cleaned/meridian59/club/util.c             index
# 2                      cleaned/meridian59/club/transfer.c           outfile
# 3                         cleaned/meridian59/bbgun/draw.c  (1<<FIX_DECIMAL)
# 4                         cleaned/meridian59/bbgun/draw.c             width
# ...                                                   ...               ...
# 557546  cleaned/notepadthing/build/psycopg2/psycopg/pq...              fmod
# 557547  cleaned/notepadthing/build/psycopg2/psycopg/pq...             fsize
# 557548  cleaned/notepadthing/build/psycopg2/psycopg/pq...               res
# 557549  cleaned/notepadthing/build/psycopg2/psycopg/pq...             error
# 557550  cleaned/notepadthing/build/psycopg2/psycopg/pq...                ex
#
#        operator        right      type_left     type_right           parent  \
# 0            ==            0            int            int          IF_STMT
# 1             +            1            int            int       PAREN_EXPR
# 2             <            0            int            int          IF_STMT
# 3             *       shrink          float          float       PAREN_EXPR
# 4             /       shrink          float          float  BINARY_OPERATOR
# ...         ...          ...            ...            ...              ...
# 557546        -  sizeof(int)  unsigned long  unsigned long   UNEXPOSED_EXPR
# 557547       ==           -1            int            int          IF_STMT
# 557548       ==           -1            int            int          IF_STMT
# 557549       ==            2            int            int          IF_STMT
# 557550       ==           -1            int            int          IF_STMT
#
#              grandparent  start_line  start_column  end_line  end_column  \
# 0          COMPOUND_STMT          53            11        53          32
# 1        BINARY_OPERATOR          75            13        75          22
# 2          COMPOUND_STMT         101             8       101          19
# 3       CSTYLE_CAST_EXPR         127            18       127          45
# 4             PAREN_EXPR         134            19       134          33
# ...                  ...         ...           ...       ...         ...
# 557546   BINARY_OPERATOR        1133            30      1133          48
# 557547     COMPOUND_STMT        1134            13      1134          24
# 557548           IF_STMT        1281            18      1281          27
# 557549     COMPOUND_STMT        1288            13      1288          23
# 557550     COMPOUND_STMT        1496            13      1496          21
#
#         labels
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 557546       0
# 557547       0
# 557548       0
# 557549       0
# 557550       0
#
# [557551 rows x 13 columns]

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 556420 entries, 0 to 557550
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   file          556420 non-null  object
#  1   left          556420 non-null  object
#  2   operator      556420 non-null  object
#  3   right         556420 non-null  object
#  4   type_left     556420 non-null  object
#  5   type_right    556420 non-null  object
#  6   parent        556420 non-null  object
#  7   grandparent   556420 non-null  object
#  8   start_line    556420 non-null  int64
#  9   start_column  556420 non-null  int64
#  10  end_line      556420 non-null  int64
#  11  end_column    556420 non-null  int64
#  12  labels        556420 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 59.4+ MB

# %%
df = df[df["operator"].isin(swappable_operator.keys())]

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.1, random_state=42)

df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train
# Out:
#                                                      file  \
# 0         cleaned/lighttpd2/src/common/angel_connection.c
# 1       cleaned/linux/drivers/staging/comedi/drivers/a...
# 2       cleaned/metamage_1/mac/contrib/Apple/MoreFiles...
# 3                  cleaned/pcsx_rearmed/libpcsxcore/sio.c
# 4        cleaned/asf_mapready/src/libasf_insar/baseline.c
# ...                                                   ...
# 500388  cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...
# 500389         cleaned/open-watcom/contrib/torture/s244.c
# 500390  cleaned/asuswrt-merlin/release/src-rt-6.x.4708...
# 500391                      cleaned/faangband/src/jewel.c
# 500392         cleaned/uclibc/librt/clock_getcpuclockid.c
#
#                                   left operator                  right  \
# 0                     i->value.fds.pos        <  i->value.fds.fds->len
# 1                         samplesinbuf        *          sizeof(short)
# 2                          srcDataBlks        /     dstBlksPerAllocBlk
# 3                                  mcd       !=                      1
# 4                                    i        <                N_STVEC
# ...                                ...      ...                    ...
# 500388  __builtin_islessequal(5.0,4.0)       !=                      0
# 500389                            a[j]       !=                 a[j+1]
# 500390             Packet->DataOffset8       <<                      3
# 500391                          choice       ==                      5
# 500392                             pid       !=                      0
#
#                type_left        type_right           parent      grandparent  \
# 0       <dependent type>  <dependent type>          IF_STMT        CASE_STMT
# 1          unsigned long     unsigned long  BINARY_OPERATOR          IF_STMT
# 2          unsigned long     unsigned long       PAREN_EXPR  BINARY_OPERATOR
# 3                    int               int  BINARY_OPERATOR          IF_STMT
# 4                    int               int         FOR_STMT    COMPOUND_STMT
# ...                  ...               ...              ...              ...
# 500388               int               int          IF_STMT    COMPOUND_STMT
# 500389            double            double          IF_STMT         FOR_STMT
# 500390  <dependent type>               int       PAREN_EXPR  BINARY_OPERATOR
# 500391               int               int       PAREN_EXPR  BINARY_OPERATOR
# 500392             pid_t               int  BINARY_OPERATOR          IF_STMT
#
#         start_line  start_column  end_line  end_column  labels
# 0               77             8        77          48       0
# 1              742             6       742          34       0
# 2              224            20       224          52       0
# 3              399             6       399          14       0
# 4               44            12        44          21       0
# ...            ...           ...       ...         ...     ...
# 500388          32             7        32          42       0
# 500389          33            27        33          41       0
# 500390         855            64       855          88       0
# 500391        2353            12      2353          23       0
# 500392          89             7        89          15       0
#
# [500393 rows x 13 columns]

# %%
df_test
# Out:
#                                                     file  \
# 0      cleaned/c30-linux/pic30-gcc/gcc-4.0.2/gcc-4.0....
# 1      cleaned/asuswrt-merlin/release/src/router/gdb/...
# 2                            cleaned/studipet2012/refs.c
# 3      cleaned/freeswitch/libs/freetdm/src/ftmod/ftmo...
# 4                     cleaned/igraph/src/lapack/dsaitr.c
# ...                                                  ...
# 55595  cleaned/blensor/source/blender/bmesh/operators...
# 55596  cleaned/vlc/modules/audio_filter/channel_mixer...
# 55597  cleaned/openjdk-fontfix/openjdk7/jdk/src/solar...
# 55598                cleaned/quake3/code/game/g_active.c
# 55599           cleaned/openafs/tests/auth/superuser-t.c
#
#                                      left operator           right  \
# 0                                    p[0]       ==             's'
# 1                                      gr       <=               5
# 2                                       p        <      packed->nr
# 3                             ccSpan->t16       ==               0
# 4                    *(unsignedchar*)bmat       ==             'I'
# ...                                   ...      ...             ...
# 55595                      el_store_a_len        >  el_store_b_len
# 55596                            p_src[1]        /               2
# 55597                   sampleSizeInBytes       ==               4
# 55598                                msec        >             200
# 55599  afsconf_AddIdentity(dir,anotherId)       ==               0
#
#               type_left type_right           parent      grandparent  \
# 0                   int        int       PAREN_EXPR  BINARY_OPERATOR
# 1                   int        int          IF_STMT    COMPOUND_STMT
# 2                   int        int  BINARY_OPERATOR       WHILE_STMT
# 3      <dependent type>        int          IF_STMT    COMPOUND_STMT
# 4                   int        int          IF_STMT          IF_STMT
# ...                 ...        ...              ...              ...
# 55595               int        int          IF_STMT    COMPOUND_STMT
# 55596             float      float  BINARY_OPERATOR  BINARY_OPERATOR
# 55597               int        int  BINARY_OPERATOR          IF_STMT
# 55598               int        int          IF_STMT    COMPOUND_STMT
# 55599               int        int        CALL_EXPR    COMPOUND_STMT
#
#        start_line  start_column  end_line  end_column  labels
# 0             457             9       457          20       0
# 1            2091            10      2091          17       0
# 2             727             9       727          23       0
# 3            3151             7      3151          23       0
# 4             602            16       602          45       0
# ...           ...           ...       ...         ...     ...
# 55595         208             6       208          37       0
# 55596         181            38       181          50       0
# 55597          88             9        88          31       0
# 55598         788             7       788          17       0
# 55599         124             8       124          48       0
#
# [55600 rows x 13 columns]

# %%
def generate_random_swappable_operator(operator):
    possible_swaps = swappable_operator[operator]
    rd = random.randint(0, len(possible_swaps) - 1)
    return possible_swaps[rd]

# %%
generate_random_swappable_operator("<=")
# Out:
# '!='

# %%
print("Total:", len(df_train.index))

neg_train_array = []
count = 0

for index, row in df_train.iterrows():
    row["operator"] = generate_random_swappable_operator(row["operator"])
    row["labels"] = 1
    
    neg_train_array.append(row.values)
    
    count += 1
    if count % 25000 == 0:
        print(count)

df_train_neg = pd.DataFrame(neg_train_array, columns=df.columns)
df_train = pd.concat([df_train, df_train_neg])
df_train
# Out:
# Total: 500393
# 25000
# 50000
# 75000
# 100000
# 125000
# 150000
# 175000
# 200000
# 225000
# 250000
# 275000
# 300000
# 325000
# 350000
# 375000
# 400000
# 425000
# 450000
# 475000
# 500000
#                                                      file  \
# 0         cleaned/lighttpd2/src/common/angel_connection.c
# 1       cleaned/linux/drivers/staging/comedi/drivers/a...
# 2       cleaned/metamage_1/mac/contrib/Apple/MoreFiles...
# 3                  cleaned/pcsx_rearmed/libpcsxcore/sio.c
# 4        cleaned/asf_mapready/src/libasf_insar/baseline.c
# ...                                                   ...
# 500388  cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...
# 500389         cleaned/open-watcom/contrib/torture/s244.c
# 500390  cleaned/asuswrt-merlin/release/src-rt-6.x.4708...
# 500391                      cleaned/faangband/src/jewel.c
# 500392         cleaned/uclibc/librt/clock_getcpuclockid.c
#
#                                   left operator                  right  \
# 0                     i->value.fds.pos        <  i->value.fds.fds->len
# 1                         samplesinbuf        *          sizeof(short)
# 2                          srcDataBlks        /     dstBlksPerAllocBlk
# 3                                  mcd       !=                      1
# 4                                    i        <                N_STVEC
# ...                                ...      ...                    ...
# 500388  __builtin_islessequal(5.0,4.0)        >                      0
# 500389                            a[j]       >=                 a[j+1]
# 500390             Packet->DataOffset8       >>                      3
# 500391                          choice        =                      5
# 500392                             pid       ==                      0
#
#                type_left        type_right           parent      grandparent  \
# 0       <dependent type>  <dependent type>          IF_STMT        CASE_STMT
# 1          unsigned long     unsigned long  BINARY_OPERATOR          IF_STMT
# 2          unsigned long     unsigned long       PAREN_EXPR  BINARY_OPERATOR
# 3                    int               int  BINARY_OPERATOR          IF_STMT
# 4                    int               int         FOR_STMT    COMPOUND_STMT
# ...                  ...               ...              ...              ...
# 500388               int               int          IF_STMT    COMPOUND_STMT
# 500389            double            double          IF_STMT         FOR_STMT
# 500390  <dependent type>               int       PAREN_EXPR  BINARY_OPERATOR
# 500391               int               int       PAREN_EXPR  BINARY_OPERATOR
# 500392             pid_t               int  BINARY_OPERATOR          IF_STMT
#
#         start_line  start_column  end_line  end_column  labels
# 0               77             8        77          48       0
# 1              742             6       742          34       0
# 2              224            20       224          52       0
# 3              399             6       399          14       0
# 4               44            12        44          21       0
# ...            ...           ...       ...         ...     ...
# 500388          32             7        32          42       1
# 500389          33            27        33          41       1
# 500390         855            64       855          88       1
# 500391        2353            12      2353          23       1
# 500392          89             7        89          15       1
#
# [1000786 rows x 13 columns]

# %%
print("Total:", len(df_test.index))

neg_test_array = []
count = 0

for index, row in df_test.iterrows():
    row["operator"] = generate_random_swappable_operator(row["operator"])
    row["labels"] = 1
    
    neg_test_array.append(row.values)
    
    count += 1
    if count % 25000 == 0:
        print(count)

df_test_neg = pd.DataFrame(neg_test_array, columns=df.columns)
df_test = pd.concat([df_test, df_test_neg])
df_test
# Out:
# Total: 55600
# 25000
# 50000
#                                                     file  \
# 0      cleaned/c30-linux/pic30-gcc/gcc-4.0.2/gcc-4.0....
# 1      cleaned/asuswrt-merlin/release/src/router/gdb/...
# 2                            cleaned/studipet2012/refs.c
# 3      cleaned/freeswitch/libs/freetdm/src/ftmod/ftmo...
# 4                     cleaned/igraph/src/lapack/dsaitr.c
# ...                                                  ...
# 55595  cleaned/blensor/source/blender/bmesh/operators...
# 55596  cleaned/vlc/modules/audio_filter/channel_mixer...
# 55597  cleaned/openjdk-fontfix/openjdk7/jdk/src/solar...
# 55598                cleaned/quake3/code/game/g_active.c
# 55599           cleaned/openafs/tests/auth/superuser-t.c
#
#                                      left operator           right  \
# 0                                    p[0]       ==             's'
# 1                                      gr       <=               5
# 2                                       p        <      packed->nr
# 3                             ccSpan->t16       ==               0
# 4                    *(unsignedchar*)bmat       ==             'I'
# ...                                   ...      ...             ...
# 55595                      el_store_a_len        <  el_store_b_len
# 55596                            p_src[1]        +               2
# 55597                   sampleSizeInBytes       >=               4
# 55598                                msec       !=             200
# 55599  afsconf_AddIdentity(dir,anotherId)        >               0
#
#               type_left type_right           parent      grandparent  \
# 0                   int        int       PAREN_EXPR  BINARY_OPERATOR
# 1                   int        int          IF_STMT    COMPOUND_STMT
# 2                   int        int  BINARY_OPERATOR       WHILE_STMT
# 3      <dependent type>        int          IF_STMT    COMPOUND_STMT
# 4                   int        int          IF_STMT          IF_STMT
# ...                 ...        ...              ...              ...
# 55595               int        int          IF_STMT    COMPOUND_STMT
# 55596             float      float  BINARY_OPERATOR  BINARY_OPERATOR
# 55597               int        int  BINARY_OPERATOR          IF_STMT
# 55598               int        int          IF_STMT    COMPOUND_STMT
# 55599               int        int        CALL_EXPR    COMPOUND_STMT
#
#        start_line  start_column  end_line  end_column  labels
# 0             457             9       457          20       0
# 1            2091            10      2091          17       0
# 2             727             9       727          23       0
# 3            3151             7      3151          23       0
# 4             602            16       602          45       0
# ...           ...           ...       ...         ...     ...
# 55595         208             6       208          37       1
# 55596         181            38       181          50       1
# 55597          88             9        88          31       1
# 55598         788             7       788          17       1
# 55599         124             8       124          48       1
#
# [111200 rows x 13 columns]

# %%
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)
df_train
# Out:
#                                                       file  \
# 0        cleaned/up4dar-os/up4dar-os/src/up_dstar/fixpo...
# 1        cleaned/msm7x30-3.4.x-naa/drivers/net/ethernet...
# 2                          cleaned/q2pro/src/client/http.c
# 3        cleaned/msm7x30-3.4.x-naa/drivers/staging/rts_...
# 4        cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...
# ...                                                    ...
# 1000781         cleaned/mosync/tools/pipe-tool/filealloc.c
# 1000782                           cleaned/perl-tk/tkGlue.c
# 1000783        cleaned/dd-wrt/src/router/iptraf/src/serv.c
# 1000784  cleaned/mythtv/mythtv/libs/libmythtv/recorders...
# 1000785           cleaned/ox820-2.6-linux/fs/cifs/smbdes.c
#
#                          left operator                    right  \
# 0                           d        <                        0
# 1              res->com.state       ==        RES_MTT_ALLOCATED
# 2                    response       >>                      100
# 3        CHK_SDIO_EXIST(chip)       &&  !CHK_SDIO_IGNORED(chip)
# 4                           b       ==                        0
# ...                       ...      ...                      ...
# 1000781                Length        *                        1
# 1000782                     i       !=                    items
# 1000783                    br       ==                        0
# 1000784                    *p        >                     2048
# 1000785                   p16       +=                        8
#
#                 type_left       type_right           parent     grandparent  \
# 0                     int              int       WHILE_STMT   COMPOUND_STMT
# 1        <dependent type>              int          IF_STMT         IF_STMT
# 2                     int              int  BINARY_OPERATOR         IF_STMT
# 3                     int              int          IF_STMT   COMPOUND_STMT
# 4         unsigned char *  unsigned char *       PAREN_EXPR       CALL_EXPR
# ...                   ...              ...              ...             ...
# 1000781               int              int        CALL_EXPR  UNEXPOSED_EXPR
# 1000782               int              int       WHILE_STMT   COMPOUND_STMT
# 1000783               int              int          IF_STMT   COMPOUND_STMT
# 1000784      unsigned int     unsigned int  BINARY_OPERATOR         IF_STMT
# 1000785   unsigned char *              int        CALL_EXPR   COMPOUND_STMT
#
#          start_line  start_column  end_line  end_column  labels
# 0                83             9        83          14       0
# 1               589            13       589          48       1
# 2               191             9       191          23       1
# 3              1113             6      1113          53       0
# 4                49            13        49          19       0
# ...             ...           ...       ...         ...     ...
# 1000781          80            52        80          62       1
# 1000782        2526             9      2526          18       1
# 1000783        1355             7      1355          13       1
# 1000784         151            12       151          21       1
# 1000785         363            10       363          17       1
#
# [1000786 rows x 13 columns]

# %%
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True)
df_test
# Out:
#                                                      file  \
# 0       cleaned/poropy/poropy/nucleardata/nucleardata_...
# 1                              cleaned/quagga/lib/plist.c
# 2       cleaned/c30-linux/pic30-binutils/acme/gas/conf...
# 3                cleaned/fontforge/fontforge/scstylesui.c
# 4                 cleaned/open-watcom/bld/wv/c/dlgscomp.c
# ...                                                   ...
# 111195                     cleaned/uhub/src/adc/message.c
# 111196  cleaned/blensor/source/blender/editors/space_s...
# 111197  cleaned/freebsd/sys/cddl/contrib/opensolaris/u...
# 111198      cleaned/drone/lib/ffmpeg/libavcodec/jrevdct.c
# 111199  cleaned/sharpfin/src/ipk/sharpfin-base-ipk/bus...
#
#                           left operator                right  \
# 0                  cWABA92[11]        *             pow(R,3)
# 1                       maxseq        <          pentry->seq
# 2       strcasecmp(start,"a2")        >                    0
# 3                        100.0        *  hs->counter_percent
# 4                         last        /                first
# ...                        ...      ...                  ...
# 111195                    *str       >=                 '\\'
# 111196                    barh        +                    1
# 111197                       1        &                 epbs
# 111198                     d00        +                  d10
# 111199          r->rtm_src_len       !=             host_len
#
#                type_left        type_right           parent      grandparent  \
# 0                 double            double  BINARY_OPERATOR  BINARY_OPERATOR
# 1                    int               int          IF_STMT    COMPOUND_STMT
# 2                    int               int          IF_STMT          IF_STMT
# 3                 double  <dependent type>        CALL_EXPR    COMPOUND_STMT
# 4           unsigned int      unsigned int  BINARY_OPERATOR    COMPOUND_STMT
# ...                  ...               ...              ...              ...
# 111195               int               int          IF_STMT          IF_STMT
# 111196               int               int  BINARY_OPERATOR         FOR_STMT
# 111197               int               int         VAR_DECL        DECL_STMT
# 111198               int               int       PAREN_EXPR  BINARY_OPERATOR
# 111199  <dependent type>               int          IF_STMT    COMPOUND_STMT
#
#         start_line  start_column  end_line  end_column  labels
# 0              482           248       482         268       0
# 1              389            11       389          31       0
# 2             1221            14      1221          43       1
# 3             2729            30      2729          56       0
# 4               92            15        92          27       1
# ...            ...           ...       ...         ...     ...
# 111195         913            13       913          25       1
# 111196         431            18       431          26       1
# 111197         480            13       480          22       1
# 111198        1115            25      1115          34       0
# 111199         224             7       224          33       0
#
# [111200 rows x 13 columns]

# %%
df_train.to_csv("wrong_binary_operator_dataset_filtered_train.csv", sep="\t", index=False)
df_test.to_csv("wrong_binary_operator_dataset_filtered_test.csv", sep="\t", index=False)

# %%
pd.read_csv("/kaggle/working/wrong_binary_operator_dataset_filtered_train.csv", sep="\t")
# Out:
#                                                       file  \
# 0        cleaned/up4dar-os/up4dar-os/src/up_dstar/fixpo...
# 1        cleaned/msm7x30-3.4.x-naa/drivers/net/ethernet...
# 2                          cleaned/q2pro/src/client/http.c
# 3        cleaned/msm7x30-3.4.x-naa/drivers/staging/rts_...
# 4        cleaned/playbook-dev-tools/bootstrap/gcc/gcc/g...
# ...                                                    ...
# 1000781         cleaned/mosync/tools/pipe-tool/filealloc.c
# 1000782                           cleaned/perl-tk/tkGlue.c
# 1000783        cleaned/dd-wrt/src/router/iptraf/src/serv.c
# 1000784  cleaned/mythtv/mythtv/libs/libmythtv/recorders...
# 1000785           cleaned/ox820-2.6-linux/fs/cifs/smbdes.c
#
#                          left operator                    right  \
# 0                           d        <                        0
# 1              res->com.state       ==        RES_MTT_ALLOCATED
# 2                    response       >>                      100
# 3        CHK_SDIO_EXIST(chip)       &&  !CHK_SDIO_IGNORED(chip)
# 4                           b       ==                        0
# ...                       ...      ...                      ...
# 1000781                Length        *                        1
# 1000782                     i       !=                    items
# 1000783                    br       ==                        0
# 1000784                    *p        >                     2048
# 1000785                   p16       +=                        8
#
#                 type_left       type_right           parent     grandparent  \
# 0                     int              int       WHILE_STMT   COMPOUND_STMT
# 1        <dependent type>              int          IF_STMT         IF_STMT
# 2                     int              int  BINARY_OPERATOR         IF_STMT
# 3                     int              int          IF_STMT   COMPOUND_STMT
# 4         unsigned char *  unsigned char *       PAREN_EXPR       CALL_EXPR
# ...                   ...              ...              ...             ...
# 1000781               int              int        CALL_EXPR  UNEXPOSED_EXPR
# 1000782               int              int       WHILE_STMT   COMPOUND_STMT
# 1000783               int              int          IF_STMT   COMPOUND_STMT
# 1000784      unsigned int     unsigned int  BINARY_OPERATOR         IF_STMT
# 1000785   unsigned char *              int        CALL_EXPR   COMPOUND_STMT
#
#          start_line  start_column  end_line  end_column  labels
# 0                83             9        83          14       0
# 1               589            13       589          48       1
# 2               191             9       191          23       1
# 3              1113             6      1113          53       0
# 4                49            13        49          19       0
# ...             ...           ...       ...         ...     ...
# 1000781          80            52        80          62       1
# 1000782        2526             9      2526          18       1
# 1000783        1355             7      1355          13       1
# 1000784         151            12       151          21       1
# 1000785         363            10       363          17       1
#
# [1000786 rows x 13 columns]

# %%
pd.read_csv("/kaggle/working/wrong_binary_operator_dataset_filtered_test.csv", sep="\t")
# Out:
#                                                      file  \
# 0       cleaned/poropy/poropy/nucleardata/nucleardata_...
# 1                              cleaned/quagga/lib/plist.c
# 2       cleaned/c30-linux/pic30-binutils/acme/gas/conf...
# 3                cleaned/fontforge/fontforge/scstylesui.c
# 4                 cleaned/open-watcom/bld/wv/c/dlgscomp.c
# ...                                                   ...
# 111195                     cleaned/uhub/src/adc/message.c
# 111196  cleaned/blensor/source/blender/editors/space_s...
# 111197  cleaned/freebsd/sys/cddl/contrib/opensolaris/u...
# 111198      cleaned/drone/lib/ffmpeg/libavcodec/jrevdct.c
# 111199  cleaned/sharpfin/src/ipk/sharpfin-base-ipk/bus...
#
#                           left operator                right  \
# 0                  cWABA92[11]        *             pow(R,3)
# 1                       maxseq        <          pentry->seq
# 2       strcasecmp(start,"a2")        >                    0
# 3                        100.0        *  hs->counter_percent
# 4                         last        /                first
# ...                        ...      ...                  ...
# 111195                    *str       >=                 '\\'
# 111196                    barh        +                    1
# 111197                       1        &                 epbs
# 111198                     d00        +                  d10
# 111199          r->rtm_src_len       !=             host_len
#
#                type_left        type_right           parent      grandparent  \
# 0                 double            double  BINARY_OPERATOR  BINARY_OPERATOR
# 1                    int               int          IF_STMT    COMPOUND_STMT
# 2                    int               int          IF_STMT          IF_STMT
# 3                 double  <dependent type>        CALL_EXPR    COMPOUND_STMT
# 4           unsigned int      unsigned int  BINARY_OPERATOR    COMPOUND_STMT
# ...                  ...               ...              ...              ...
# 111195               int               int          IF_STMT          IF_STMT
# 111196               int               int  BINARY_OPERATOR         FOR_STMT
# 111197               int               int         VAR_DECL        DECL_STMT
# 111198               int               int       PAREN_EXPR  BINARY_OPERATOR
# 111199  <dependent type>               int          IF_STMT    COMPOUND_STMT
#
#         start_line  start_column  end_line  end_column  labels
# 0              482           248       482         268       0
# 1              389            11       389          31       0
# 2             1221            14      1221          43       1
# 3             2729            30      2729          56       0
# 4               92            15        92          27       1
# ...            ...           ...       ...         ...     ...
# 111195         913            13       913          25       1
# 111196         431            18       431          26       1
# 111197         480            13       480          22       1
# 111198        1115            25      1115          34       0
# 111199         224             7       224          33       0
#
# [111200 rows x 13 columns]
