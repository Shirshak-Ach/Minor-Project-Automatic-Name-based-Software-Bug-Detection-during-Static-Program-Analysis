# %%
# Import necessary modules
from sklearn.metrics import roc_curve

# Compute predicted probabilities: y_pred_prob
y_pred_prob = logreg.predict_proba(X_test)[:,1]

# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
# learning_rate = [2e-4,5e-4,5e-5,2e-5,5e-6]
# batch_size = [32,64]
# num_epoch = [2,5,8,10,17,25]

# %%
print(learning_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print(learning_rate)
#
# NameError: name 'learning_rate' is not defined

# %%
lr = np.array(learning_rate)
bs = np.array(batch_size)
ne = np.array(num_epoch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 lr = np.array(learning_rate)
#       2 bs = np.array(batch_size)
#       3 ne = np.array(num_epoch)
#
# NameError: name 'learning_rate' is not defined

# %%
print(lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 print(lr)
#
# NameError: name 'lr' is not defined

# %%
lr.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 lr.shape
#
# NameError: name 'lr' is not defined

# %%
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.10787434422876366, 0.014452421710066995, 'Z')

# %%
ax.scatter(lr, bs, ne)
plt.show(block=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 ax.scatter(lr, bs, ne)
#       2 plt.show(block=True)
#
# NameError: name 'lr' is not defined

# %%
X = np.random.rand(100)
print(X)
# Out:
# [0.66133287 0.8627223  0.0202993  0.27298775 0.44082399 0.32965772
#  0.3134886  0.94595825 0.07357264 0.59280938 0.43266216 0.73913134
#  0.92937418 0.52683142 0.50897343 0.99426262 0.26189175 0.44699307
#  0.51510068 0.71312238 0.60237815 0.4629939  0.52859714 0.75313329
#  0.08475219 0.92098731 0.20808703 0.45963764 0.81014425 0.5396584
#  0.85413027 0.27328909 0.26304456 0.81206512 0.25064996 0.42302516
#  0.5790497  0.18131402 0.01817806 0.69133261 0.17878257 0.21964907
#  0.70726398 0.26857696 0.01799196 0.59367682 0.40488364 0.07397172
#  0.13402936 0.2182506  0.59392997 0.2583591  0.04618777 0.0658012
#  0.82252097 0.74900574 0.30251028 0.3117443  0.67055657 0.26643039
#  0.61972102 0.62868249 0.48354237 0.53025214 0.86055768 0.28538473
#  0.58457777 0.35170411 0.12384185 0.47458175 0.03672027 0.4935568
#  0.31668145 0.75884613 0.37674289 0.72046423 0.34849707 0.4280725
#  0.22282236 0.77581871 0.92489937 0.39514013 0.75034682 0.40124354
# ...

# %%
# Generate some sample data
X = []
Y = []
Z = []

# %%
learning_rate = [2e-6, 2e-5, 2e-4, 2e-3]
batch_size = [32, 64]
# num_epoch = [2,5,8,10,17,25]

# %%
for i in learning_rate:
    for j in batch_size:
            X.append(i)
            Y.append(j)

# %%
X
# Out:
# [2e-06, 2e-06, 2e-05, 2e-05, 0.0002, 0.0002, 0.002, 0.002]

# %%
Y
# Out:
# [32, 64, 32, 64, 32, 64, 32, 64]

# %%
fig, ax= plt.subplots(figsize=(16, 8))
plt.xlabel('Learning Rate',fontsize=32)
plt.ylabel('Batch Size',fontsize=32)
plt.rcParams['font.family'] = 'Times New Roman'
ax.tick_params(axis='both', which='major', labelsize=32)

# ax.set_xticks([2e-3, 2e-4, 2e-5, 2e-6])
ax.set_yticks([0, 32, 64, 128])
ax.set_xscale("log")


# ax.set_xticklabels([0,2e-6,2e-5,2e-4,2e-3,2e-2])

ax.set_xlim([0, 2e-7])
ax.set_ylim([0, 128])

# ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=18)

plt.scatter(X,Y)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_33640\1831715353.py:14: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim([0, 2e-7])

# %%
np.log10(10)
# Out:
# 1.0

# %%
for i in learning_rate:
    for j in batch_size:
        for k in num_epoch:
            X.append(i)
            Y.append(j)
            Z.append(k)

# %%
X

# %%
# Create a 3D plot
fig = plt.figure()
ax = Axes3D(fig)

# Plot the surface
ax.scatter(X, Y, Z)

# Set the labels for the axes
ax.set_xlabel('Learning Rate')
ax.set_ylabel('Batch Size')
ax.set_zlabel('Number of Epoch')
ax.set_title("Various hyperparameter Visualization")

# Show the plot
plt.show()

# %%
5e-4;16;5
5e-5;32;8
2e-5;64;10
5e-6;128;17
2e-6;256;25

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
df = px.data.iris() 
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width', color='species') 
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
z1 = np.array([
    [8.83,8.89,8.81,8.87,8.9,8.87],
    [8.89,8.94,8.85,8.94,8.96,8.92],
    [8.84,8.9,8.82,8.92,8.93,8.91],
    [8.79,8.85,8.79,8.9,8.94,8.92],
    [8.79,8.88,8.81,8.9,8.95,8.92],
    [8.8,8.82,8.78,8.91,8.94,8.92],
    [8.75,8.78,8.77,8.91,8.95,8.92],
    [8.8,8.8,8.77,8.91,8.95,8.94],
    [8.74,8.81,8.76,8.93,8.98,8.99],
    [8.89,8.99,8.92,9.1,9.13,9.11],
    [8.97,8.97,8.91,9.09,9.11,9.11],
    [9.04,9.08,9.05,9.25,9.28,9.27],
    [9,9.01,9,9.2,9.23,9.2],
    [8.99,8.99,8.98,9.18,9.2,9.19],
    [8.93,8.97,8.97,9.18,9.2,9.18]
])

# %%
z1

# %%
z1.shape

# %%
learning_rate = [2e-4,5e-4,5e-5,2e-5,5e-6]
batch_size = [8,16,32,64,128,256]
num_epoch = [2,5,8,10,17,25]
lr = np.array(learning_rate)
bs = np.array(batch_size)
ne = np.array(num_epoch)

# %%
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

# %%
z_data

# %%
import plotly.graph_objects as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
z_data

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
5e-4;16;5
5e-5;32;8
2e-5;64;10
5e-6;128;17
2e-6;256;25

# %%
data = [[[5e-4,5e-5,2e-5,5e-6,2e-6],   
        [16,32,64,128,256],
         [5,8,10,17,25],
        ],
       ]

# %%
data = np.array(data)

# %%
data

# %%
data.shape

# %%
# Create axis
axes = [5, 5, 5]
 
# Create Data
data = np.ones(axes, dtype=np.bool)
 
# Control Transparency
alpha = 0.9
 
# Control colour
colors = np.empty(axes + [4], dtype=np.float32)
 
colors[0] = [1, 0, 0, alpha]  # red
colors[1] = [0, 1, 0, alpha]  # green
colors[2] = [0, 0, 1, alpha]  # blue
colors[3] = [1, 1, 0, alpha]  # yellow
colors[4] = [1, 1, 1, alpha]  # grey
 
# Plot figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Voxels is used to customizations of
# the sizes, positions and colors.
ax.voxels(data, facecolors=colors, edgecolors='grey')

# %%
data

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.arange(-5,5,0.1)
y = np.arange(-5,5,0.1)
X,Y = np.meshgrid(x,y)
Z = X*np.exp(-X - Y)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

# Plot a 3D surface
ax.plot_surface(X, Y, Z)

plt.show()

# %%
30 + fact2a*fact2b;

# %%
# multimodal test function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
 
# objective function
def objective(x, y):
    return (x**2+y-11)**2 +(x+y**2-7)**2

# %%
# define range for input
r_min, r_max = -3.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
plt.title("Himmelblau's function")
plt.xlabel('x values ranging from -2 to 4')
plt.ylabel('y values ranging from -2 to 4')
# show the plot
pyplot.show()
